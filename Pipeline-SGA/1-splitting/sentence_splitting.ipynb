# %%
#utils
import pandas as pd
import os
import numpy as np
from nltk.tokenize import word_tokenize

# %%
#dataset_names = [
#    'testset_D2T-1-CFA_WebNLG_CounterFactual',
#    'testset_D2T-1-FA_WebNLG_Factual',
#    'testset_D2T-1-FI_WebNLG_Fictional',
#    'testset_D2T-2-CFA_Wikidata_CounterFactual',
#    'testset_D2T-2-FA_Wikidata_Factual',
#    'testset_D2T-2-FI_Wikidata_Fictional',
#]

dataset_names = [
    '79351_test_TC_en',
]

# %% [markdown]
# ## FUNCTIONS

# %%
def merge_dicts(dict1, dict2):
    #print(f'START MERGE_DICTS')
    merged_dict = {}
    for key, value in dict1.items():
        merged_dict[key] = dict1[key]

        if key in dict2:
            for triple in value:
                flag = True
                for key, value in merged_dict.items():
                    if triple in value:
                        flag = False
                        break

                if flag:
                    merged_dict[key].insert(0, triple)
        else:
            merged_dict[key] = value

    keys = list(merged_dict.keys())
    values = list(merged_dict.values())
    keys = [str(i) for i in range(len(keys))]
    merged_dict = dict(zip(keys, values))
    print(f'merged_dict: {merged_dict}')

    #print(f'END MERGE_DICTS')
    return merged_dict

def split_mixed(triples):
    subject_dict = {}
    object_dict = {}
    #print(f'START SPLIT_MIXED')
    for triple in triples:
        triple = triple.split(' ')

        if len(triple) > 1:
            # sibling
            subject = triple[0]

            if subject in subject_dict:
                subject_dict[subject].append(triple)
            else:
                subject_dict[subject] = [triple]

            # chain
            object = triple[0]

            for triple in triples:
                triple = triple.split(' ')

                if len(triple) > 1:
                    if triple[2] == object:
                        if object in object_dict:
                            object_dict[object].append(triple)
                        else:
                            object_dict[object] = [triple]

    print(f'subject_dict: {subject_dict}')
    print(f'object_dict: {object_dict}')

    #print(f'subject_dict: {subject_dict}')
    #print(f'object_dict: {object_dict}')

    merged_dict = merge_dicts(subject_dict, object_dict)

    #print(f'END SPLIT_MIXED')
    return merged_dict

# %%
#splitta il dizionario in gruppi di 3 nel caso ci fossero chiavi con piu di 3 valori
def split_dict(dict_to_split):
    new_dict = {}
    for key, value in dict_to_split.items():
        num_chunks = (len(value) + 2) // 3  # Calcoliamo il numero di chunk necessari
        for i in range(num_chunks):
            new_key = f"{key}_{i}" if i > 0 else key  # Creiamo una nuova chiave con indice se necessario
            start = i * 3
            end = min((i + 1) * 3, len(value))
            new_dict[new_key] = value[start:end]  # Aggiungiamo i valori corrispondenti
    return new_dict

# %%
def create_dict_with_max_values(array, max_values_per_key):
    array = [triple for triple in array if triple.strip()]  # Rimuovi le stringhe vuote
    result_dict = {}
    current_key_index = 0
    current_key_values = []
    for triple in array:
        current_key_values.append(triple.split(' '))
        if len(current_key_values) == max_values_per_key:
            result_dict[current_key_index] = current_key_values
            current_key_index += 1
            current_key_values = []
    # Aggiungi eventuali valori rimanenti
    if current_key_values:
        result_dict[current_key_index] = current_key_values
    return result_dict

# %% [markdown]
# ## MAIN

# %%
for dataset_name in dataset_names:
    print(f'Processing {dataset_name}')
    #dataset = pd.read_csv(f'../GEM/data_formatted/{dataset_name}.csv')
    full_dataset = pd.read_csv(f'{dataset_name}.csv')
    # get only 1000 random rows from dataset with random seed = 42
    perc_d = 1000 / len(full_dataset)
    dataset = full_dataset.sample(frac=perc_d, random_state=42)

    # refresh index
    dataset = dataset.reset_index(drop=True)

    triples_dict = {}
    j = 0
    for i in range(len(dataset)):
        triples = dataset['triple'][i].split(' | ')

        if (dataset['shape_type'][i] == 'mixed' or dataset['shape_type'][i] == 'NA' or dataset['shape_type'][i] == 'unknown') and dataset['size'][i] > 2:
            print('1', triples)
            dictionary = split_mixed(triples)
            dictionary = split_dict(dictionary)
        else:
            dictionary = create_dict_with_max_values(triples, 3)

        
            
        for key, value in dictionary.items():
            value_text = ''
            for triple in value:
                value_text += ' '.join(triple) + ' '

            triples_dict[j] = {
                'id': i,
                'triples': value_text,
                'data_unit' : dataset['triple'][i],
                'actual' : dataset['sentence'][i],
                'shape' : dataset['shape'][i],
                'shape_type' : dataset['shape_type'][i],
                'local_size' : len(value),
                'size' : dataset['size'][i],
            }
            j += 1

    triples_df = pd.DataFrame.from_dict(triples_dict, "index")
    triples_df.to_csv(f'{dataset_name}_splitted.csv', index=False)

triples_df.head()
# Out:
# Processing 79351_test_TC_en
# 1 ['Adams_County,_Pennsylvania hasToItsWest Franklin_County,_Pennsylvania', '11th_Mississippi_Infantry_Monument established 2000', '11th_Mississippi_Infantry_Monument location Adams_County,_Pennsylvania', '11th_Mississippi_Infantry_Monument category Contributing_property', '']
# subject_dict: {'Adams_County,_Pennsylvania': [['Adams_County,_Pennsylvania', 'hasToItsWest', 'Franklin_County,_Pennsylvania']], '11th_Mississippi_Infantry_Monument': [['11th_Mississippi_Infantry_Monument', 'established', '2000'], ['11th_Mississippi_Infantry_Monument', 'location', 'Adams_County,_Pennsylvania'], ['11th_Mississippi_Infantry_Monument', 'category', 'Contributing_property']]}
# object_dict: {'Adams_County,_Pennsylvania': [['11th_Mississippi_Infantry_Monument', 'location', 'Adams_County,_Pennsylvania']]}
# merged_dict: {'0': [['Adams_County,_Pennsylvania', 'hasToItsWest', 'Franklin_County,_Pennsylvania']], '1': [['11th_Mississippi_Infantry_Monument', 'established', '2000'], ['11th_Mississippi_Infantry_Monument', 'location', 'Adams_County,_Pennsylvania'], ['11th_Mississippi_Infantry_Monument', 'category', 'Contributing_property']]}
# 1 ['BBC city Broadcasting_House', 'Bananaman starring Bill_Oddie', 'Bananaman broadcastedBy BBC', '']
# subject_dict: {'BBC': [['BBC', 'city', 'Broadcasting_House']], 'Bananaman': [['Bananaman', 'starring', 'Bill_Oddie'], ['Bananaman', 'broadcastedBy', 'BBC']]}
# object_dict: {'BBC': [['Bananaman', 'broadcastedBy', 'BBC']]}
# merged_dict: {'0': [['BBC', 'city', 'Broadcasting_House']], '1': [['Bananaman', 'starring', 'Bill_Oddie'], ['Bananaman', 'broadcastedBy', 'BBC']]}
# 1 ['Adolfo_Suárez_Madrid–Barajas_Airport operatingOrganisation ENAIRE', 'Adolfo_Suárez_Madrid–Barajas_Airport location Alcobendas', 'ENAIRE city Madrid', 'Adolfo_Suárez_Madrid–Barajas_Airport runwayLength 3500.0', 'Adolfo_Suárez_Madrid–Barajas_Airport runwayName "14L/32R"', '']
# subject_dict: {'Adolfo_Suárez_Madrid–Barajas_Airport': [['Adolfo_Suárez_Madrid–Barajas_Airport', 'operatingOrganisation', 'ENAIRE'], ['Adolfo_Suárez_Madrid–Barajas_Airport', 'location', 'Alcobendas'], ['Adolfo_Suárez_Madrid–Barajas_Airport', 'runwayLength', '3500.0'], ['Adolfo_Suárez_Madrid–Barajas_Airport', 'runwayName', '"14L/32R"']], 'ENAIRE': [['ENAIRE', 'city', 'Madrid']]}
# object_dict: {'ENAIRE': [['Adolfo_Suárez_Madrid–Barajas_Airport', 'operatingOrganisation', 'ENAIRE']]}
# merged_dict: {'0': [['Adolfo_Suárez_Madrid–Barajas_Airport', 'operatingOrganisation', 'ENAIRE'], ['Adolfo_Suárez_Madrid–Barajas_Airport', 'location', 'Alcobendas'], ['Adolfo_Suárez_Madrid–Barajas_Airport', 'runwayLength', '3500.0'], ['Adolfo_Suárez_Madrid–Barajas_Airport', 'runwayName', '"14L/32R"']], '1': [['ENAIRE', 'city', 'Madrid']]}
# 1 ['Mexico currency Mexican_peso', 'Mexico demonym Mexicans', 'Bionico course Dessert', 'Bionico region Guadalajara', 'Mexico leader Silvano_Aureoles_Conejo', 'Bionico ingredient Raisin', 'Bionico country Mexico', '']
# subject_dict: {'Mexico': [['Mexico', 'currency', 'Mexican_peso'], ['Mexico', 'demonym', 'Mexicans'], ['Mexico', 'leader', 'Silvano_Aureoles_Conejo']], 'Bionico': [['Bionico', 'course', 'Dessert'], ['Bionico', 'region', 'Guadalajara'], ['Bionico', 'ingredient', 'Raisin'], ['Bionico', 'country', 'Mexico']]}
# object_dict: {'Mexico': [['Bionico', 'country', 'Mexico'], ['Bionico', 'country', 'Mexico'], ['Bionico', 'country', 'Mexico']]}
# merged_dict: {'0': [['Mexico', 'currency', 'Mexican_peso'], ['Mexico', 'demonym', 'Mexicans'], ['Mexico', 'leader', 'Silvano_Aureoles_Conejo']], '1': [['Bionico', 'course', 'Dessert'], ['Bionico', 'region', 'Guadalajara'], ['Bionico', 'ingredient', 'Raisin'], ['Bionico', 'country', 'Mexico']]}
# 1 ['Hypermarcas industry Pharmaceuticals', 'Hypermarcas location São_Paulo', 'Hypermarcas location Brazil', 'Brazil leader Michel_Temer', 'Brazil leader Cármen_Lúcia', '']
# subject_dict: {'Hypermarcas': [['Hypermarcas', 'industry', 'Pharmaceuticals'], ['Hypermarcas', 'location', 'São_Paulo'], ['Hypermarcas', 'location', 'Brazil']], 'Brazil': [['Brazil', 'leader', 'Michel_Temer'], ['Brazil', 'leader', 'Cármen_Lúcia']]}
# object_dict: {'Brazil': [['Hypermarcas', 'location', 'Brazil'], ['Hypermarcas', 'location', 'Brazil']]}
# merged_dict: {'0': [['Hypermarcas', 'industry', 'Pharmaceuticals'], ['Hypermarcas', 'location', 'São_Paulo'], ['Hypermarcas', 'location', 'Brazil']], '1': [['Brazil', 'leader', 'Michel_Temer'], ['Brazil', 'leader', 'Cármen_Lúcia']]}
# 1 ['11th_Mississippi_Infantry_Monument location Adams_County,_Pennsylvania', '11th_Mississippi_Infantry_Monument municipality Gettysburg,_Pennsylvania', 'Adams_County,_Pennsylvania hasToItsSoutheast Carroll_County,_Maryland', '11th_Mississippi_Infantry_Monument category Contributing_property', 'Adams_County,_Pennsylvania hasToItsNorth Cumberland_County,_Pennsylvania', '11th_Mississippi_Infantry_Monument country "United States"', '']
# subject_dict: {'11th_Mississippi_Infantry_Monument': [['11th_Mississippi_Infantry_Monument', 'location', 'Adams_County,_Pennsylvania'], ['11th_Mississippi_Infantry_Monument', 'municipality', 'Gettysburg,_Pennsylvania'], ['11th_Mississippi_Infantry_Monument', 'category', 'Contributing_property'], ['11th_Mississippi_Infantry_Monument', 'country', '"United', 'States"']], 'Adams_County,_Pennsylvania': [['Adams_County,_Pennsylvania', 'hasToItsSoutheast', 'Carroll_County,_Maryland'], ['Adams_County,_Pennsylvania', 'hasToItsNorth', 'Cumberland_County,_Pennsylvania']]}
# object_dict: {'Adams_County,_Pennsylvania': [['11th_Mississippi_Infantry_Monument', 'location', 'Adams_County,_Pennsylvania'], ['11th_Mississippi_Infantry_Monument', 'location', 'Adams_County,_Pennsylvania']]}
# merged_dict: {'0': [['11th_Mississippi_Infantry_Monument', 'location', 'Adams_County,_Pennsylvania'], ['11th_Mississippi_Infantry_Monument', 'municipality', 'Gettysburg,_Pennsylvania'], ['11th_Mississippi_Infantry_Monument', 'category', 'Contributing_property'], ['11th_Mississippi_Infantry_Monument', 'country', '"United', 'States"']], '1': [['Adams_County,_Pennsylvania', 'hasToItsSoutheast', 'Carroll_County,_Maryland'], ['Adams_County,_Pennsylvania', 'hasToItsNorth', 'Cumberland_County,_Pennsylvania']]}
# 1 ['Bootleg_Series_Volume_1:_The_Quine_Tapes recordedIn San_Francisco', 'San_Francisco utcOffset &minus;7', 'Bootleg_Series_Volume_1:_The_Quine_Tapes recordedIn United_States', 'United_States areaTotal 9833520000000.0', '']
# subject_dict: {'Bootleg_Series_Volume_1:_The_Quine_Tapes': [['Bootleg_Series_Volume_1:_The_Quine_Tapes', 'recordedIn', 'San_Francisco'], ['Bootleg_Series_Volume_1:_The_Quine_Tapes', 'recordedIn', 'United_States']], 'San_Francisco': [['San_Francisco', 'utcOffset', '&minus;7']], 'United_States': [['United_States', 'areaTotal', '9833520000000.0']]}
# object_dict: {'San_Francisco': [['Bootleg_Series_Volume_1:_The_Quine_Tapes', 'recordedIn', 'San_Francisco']], 'United_States': [['Bootleg_Series_Volume_1:_The_Quine_Tapes', 'recordedIn', 'United_States']]}
# merged_dict: {'0': [['Bootleg_Series_Volume_1:_The_Quine_Tapes', 'recordedIn', 'San_Francisco'], ['Bootleg_Series_Volume_1:_The_Quine_Tapes', 'recordedIn', 'United_States']], '1': [['San_Francisco', 'utcOffset', '&minus;7']], '2': [['United_States', 'areaTotal', '9833520000000.0']]}
# 1 ['Bootleg_Series_Volume_1:_The_Quine_Tapes recordLabel Polydor_Records', 'Universal_Music_Group location Santa_Monica,_California', 'Polydor_Records location London', 'Bootleg_Series_Volume_1:_The_Quine_Tapes recordLabel Universal_Music_Group', '']
# subject_dict: {'Bootleg_Series_Volume_1:_The_Quine_Tapes': [['Bootleg_Series_Volume_1:_The_Quine_Tapes', 'recordLabel', 'Polydor_Records'], ['Bootleg_Series_Volume_1:_The_Quine_Tapes', 'recordLabel', 'Universal_Music_Group']], 'Universal_Music_Group': [['Universal_Music_Group', 'location', 'Santa_Monica,_California']], 'Polydor_Records': [['Polydor_Records', 'location', 'London']]}
# object_dict: {'Universal_Music_Group': [['Bootleg_Series_Volume_1:_The_Quine_Tapes', 'recordLabel', 'Universal_Music_Group']], 'Polydor_Records': [['Bootleg_Series_Volume_1:_The_Quine_Tapes', 'recordLabel', 'Polydor_Records']]}
# merged_dict: {'0': [['Bootleg_Series_Volume_1:_The_Quine_Tapes', 'recordLabel', 'Polydor_Records'], ['Bootleg_Series_Volume_1:_The_Quine_Tapes', 'recordLabel', 'Universal_Music_Group']], '1': [['Universal_Music_Group', 'location', 'Santa_Monica,_California']], '2': [['Polydor_Records', 'location', 'London']]}
# 1 ['Estádio_Municipal_Coaracy_da_Mata_Fonseca location Arapiraca', 'Agremiação_Sportiva_Arapiraquense league Campeonato_Brasileiro_Série_C', 'Agremiação_Sportiva_Arapiraquense season 2015', 'Campeonato_Brasileiro_Série_C country Brazil', 'Agremiação_Sportiva_Arapiraquense numberOfMembers 17000', 'Agremiação_Sportiva_Arapiraquense ground Estádio_Municipal_Coaracy_da_Mata_Fonseca', 'Agremiação_Sportiva_Arapiraquense fullName "Agremiação Sportiva Arapiraquense"', '']
# subject_dict: {'Estádio_Municipal_Coaracy_da_Mata_Fonseca': [['Estádio_Municipal_Coaracy_da_Mata_Fonseca', 'location', 'Arapiraca']], 'Agremiação_Sportiva_Arapiraquense': [['Agremiação_Sportiva_Arapiraquense', 'league', 'Campeonato_Brasileiro_Série_C'], ['Agremiação_Sportiva_Arapiraquense', 'season', '2015'], ['Agremiação_Sportiva_Arapiraquense', 'numberOfMembers', '17000'], ['Agremiação_Sportiva_Arapiraquense', 'ground', 'Estádio_Municipal_Coaracy_da_Mata_Fonseca'], ['Agremiação_Sportiva_Arapiraquense', 'fullName', '"Agremiação', 'Sportiva', 'Arapiraquense"']], 'Campeonato_Brasileiro_Série_C': [['Campeonato_Brasileiro_Série_C', 'country', 'Brazil']]}
# object_dict: {'Estádio_Municipal_Coaracy_da_Mata_Fonseca': [['Agremiação_Sportiva_Arapiraquense', 'ground', 'Estádio_Municipal_Coaracy_da_Mata_Fonseca']], 'Campeonato_Brasileiro_Série_C': [['Agremiação_Sportiva_Arapiraquense', 'league', 'Campeonato_Brasileiro_Série_C']]}
# merged_dict: {'0': [['Estádio_Municipal_Coaracy_da_Mata_Fonseca', 'location', 'Arapiraca']], '1': [['Agremiação_Sportiva_Arapiraquense', 'league', 'Campeonato_Brasileiro_Série_C'], ['Agremiação_Sportiva_Arapiraquense', 'season', '2015'], ['Agremiação_Sportiva_Arapiraquense', 'numberOfMembers', '17000'], ['Agremiação_Sportiva_Arapiraquense', 'ground', 'Estádio_Municipal_Coaracy_da_Mata_Fonseca'], ['Agremiação_Sportiva_Arapiraquense', 'fullName', '"Agremiação', 'Sportiva', 'Arapiraquense"']], '2': [['Campeonato_Brasileiro_Série_C', 'country', 'Brazil']]}
# 1 ['Adams_County,_Pennsylvania hasToItsWest Franklin_County,_Pennsylvania', '11th_Mississippi_Infantry_Monument established 2000', '11th_Mississippi_Infantry_Monument location Adams_County,_Pennsylvania', '']
# subject_dict: {'Adams_County,_Pennsylvania': [['Adams_County,_Pennsylvania', 'hasToItsWest', 'Franklin_County,_Pennsylvania']], '11th_Mississippi_Infantry_Monument': [['11th_Mississippi_Infantry_Monument', 'established', '2000'], ['11th_Mississippi_Infantry_Monument', 'location', 'Adams_County,_Pennsylvania']]}
# object_dict: {'Adams_County,_Pennsylvania': [['11th_Mississippi_Infantry_Monument', 'location', 'Adams_County,_Pennsylvania']]}
# merged_dict: {'0': [['Adams_County,_Pennsylvania', 'hasToItsWest', 'Franklin_County,_Pennsylvania']], '1': [['11th_Mississippi_Infantry_Monument', 'established', '2000'], ['11th_Mississippi_Infantry_Monument', 'location', 'Adams_County,_Pennsylvania']]}
# 1 ['Alan_B._Miller_Hall architect Robert_A._M._Stern', 'Alan_B._Miller_Hall address "101 Ukrop Way"', 'Alan_B._Miller_Hall buildingStartDate "30 March 2007"', 'Alan_B._Miller_Hall currentTenants Mason_School_of_Business', 'Alan_B._Miller_Hall location Virginia', 'Mason_School_of_Business country United_States', 'Alan_B._Miller_Hall owner College_of_William_&_Mary', '']
# subject_dict: {'Alan_B._Miller_Hall': [['Alan_B._Miller_Hall', 'architect', 'Robert_A._M._Stern'], ['Alan_B._Miller_Hall', 'address', '"101', 'Ukrop', 'Way"'], ['Alan_B._Miller_Hall', 'buildingStartDate', '"30', 'March', '2007"'], ['Alan_B._Miller_Hall', 'currentTenants', 'Mason_School_of_Business'], ['Alan_B._Miller_Hall', 'location', 'Virginia'], ['Alan_B._Miller_Hall', 'owner', 'College_of_William_&_Mary']], 'Mason_School_of_Business': [['Mason_School_of_Business', 'country', 'United_States']]}
# object_dict: {'Mason_School_of_Business': [['Alan_B._Miller_Hall', 'currentTenants', 'Mason_School_of_Business']]}
# merged_dict: {'0': [['Alan_B._Miller_Hall', 'architect', 'Robert_A._M._Stern'], ['Alan_B._Miller_Hall', 'address', '"101', 'Ukrop', 'Way"'], ['Alan_B._Miller_Hall', 'buildingStartDate', '"30', 'March', '2007"'], ['Alan_B._Miller_Hall', 'currentTenants', 'Mason_School_of_Business'], ['Alan_B._Miller_Hall', 'location', 'Virginia'], ['Alan_B._Miller_Hall', 'owner', 'College_of_William_&_Mary']], '1': [['Mason_School_of_Business', 'country', 'United_States']]}
# 1 ['Alan_Shepard birthDate "1923-11-18"', 'Alan_Shepard deathPlace California', 'New_Hampshire bird Purple_finch', 'Alan_Shepard birthPlace New_Hampshire', '']
# subject_dict: {'Alan_Shepard': [['Alan_Shepard', 'birthDate', '"1923-11-18"'], ['Alan_Shepard', 'deathPlace', 'California'], ['Alan_Shepard', 'birthPlace', 'New_Hampshire']], 'New_Hampshire': [['New_Hampshire', 'bird', 'Purple_finch']]}
# object_dict: {'New_Hampshire': [['Alan_Shepard', 'birthPlace', 'New_Hampshire']]}
# merged_dict: {'0': [['Alan_Shepard', 'birthDate', '"1923-11-18"'], ['Alan_Shepard', 'deathPlace', 'California'], ['Alan_Shepard', 'birthPlace', 'New_Hampshire']], '1': [['New_Hampshire', 'bird', 'Purple_finch']]}
# 1 ['Liselotte_Grschebina nationality Israel', 'Israel areaTotal 20769100000.0', 'Israel officialLanguage Modern_Standard_Arabic', 'Liselotte_Grschebina birthPlace German_Empire', 'Liselotte_Grschebina training School_of_Applied_Arts_in_Stuttgart', '']
# subject_dict: {'Liselotte_Grschebina': [['Liselotte_Grschebina', 'nationality', 'Israel'], ['Liselotte_Grschebina', 'birthPlace', 'German_Empire'], ['Liselotte_Grschebina', 'training', 'School_of_Applied_Arts_in_Stuttgart']], 'Israel': [['Israel', 'areaTotal', '20769100000.0'], ['Israel', 'officialLanguage', 'Modern_Standard_Arabic']]}
# object_dict: {'Israel': [['Liselotte_Grschebina', 'nationality', 'Israel'], ['Liselotte_Grschebina', 'nationality', 'Israel']]}
# merged_dict: {'0': [['Liselotte_Grschebina', 'nationality', 'Israel'], ['Liselotte_Grschebina', 'birthPlace', 'German_Empire'], ['Liselotte_Grschebina', 'training', 'School_of_Applied_Arts_in_Stuttgart']], '1': [['Israel', 'areaTotal', '20769100000.0'], ['Israel', 'officialLanguage', 'Modern_Standard_Arabic']]}
# 1 ['Mexico currency Mexican_peso', 'Bionico course Dessert', 'Bionico region Guadalajara', 'Bionico country Mexico', '']
# subject_dict: {'Mexico': [['Mexico', 'currency', 'Mexican_peso']], 'Bionico': [['Bionico', 'course', 'Dessert'], ['Bionico', 'region', 'Guadalajara'], ['Bionico', 'country', 'Mexico']]}
# object_dict: {'Mexico': [['Bionico', 'country', 'Mexico']]}
# merged_dict: {'0': [['Mexico', 'currency', 'Mexican_peso']], '1': [['Bionico', 'course', 'Dessert'], ['Bionico', 'region', 'Guadalajara'], ['Bionico', 'country', 'Mexico']]}
# 1 ['Mexico currency Mexican_peso', 'Mexico demonym Mexicans', 'Bionico region Guadalajara', 'Bionico ingredient Granola', 'Bionico country Mexico', '']
# subject_dict: {'Mexico': [['Mexico', 'currency', 'Mexican_peso'], ['Mexico', 'demonym', 'Mexicans']], 'Bionico': [['Bionico', 'region', 'Guadalajara'], ['Bionico', 'ingredient', 'Granola'], ['Bionico', 'country', 'Mexico']]}
# object_dict: {'Mexico': [['Bionico', 'country', 'Mexico'], ['Bionico', 'country', 'Mexico']]}
# merged_dict: {'0': [['Mexico', 'currency', 'Mexican_peso'], ['Mexico', 'demonym', 'Mexicans']], '1': [['Bionico', 'region', 'Guadalajara'], ['Bionico', 'ingredient', 'Granola'], ['Bionico', 'country', 'Mexico']]}
# 1 ['Super_Capers starring Justin_Whalin', 'Justin_Whalin occupation Presenter', 'Super_Capers starring Michael_Rooker', 'Michael_Rooker birthYear 1955-01-01', '']
# subject_dict: {'Super_Capers': [['Super_Capers', 'starring', 'Justin_Whalin'], ['Super_Capers', 'starring', 'Michael_Rooker']], 'Justin_Whalin': [['Justin_Whalin', 'occupation', 'Presenter']], 'Michael_Rooker': [['Michael_Rooker', 'birthYear', '1955-01-01']]}
# object_dict: {'Justin_Whalin': [['Super_Capers', 'starring', 'Justin_Whalin']], 'Michael_Rooker': [['Super_Capers', 'starring', 'Michael_Rooker']]}
# merged_dict: {'0': [['Super_Capers', 'starring', 'Justin_Whalin'], ['Super_Capers', 'starring', 'Michael_Rooker']], '1': [['Justin_Whalin', 'occupation', 'Presenter']], '2': [['Michael_Rooker', 'birthYear', '1955-01-01']]}
# 1 ['Super_Capers distributor Lionsgate', 'Super_Capers starring Justin_Whalin', 'Super_Capers distributor Roadside_Attractions', 'Roadside_Attractions foundingYear 2003-01-01', '']
# subject_dict: {'Super_Capers': [['Super_Capers', 'distributor', 'Lionsgate'], ['Super_Capers', 'starring', 'Justin_Whalin'], ['Super_Capers', 'distributor', 'Roadside_Attractions']], 'Roadside_Attractions': [['Roadside_Attractions', 'foundingYear', '2003-01-01']]}
# object_dict: {'Roadside_Attractions': [['Super_Capers', 'distributor', 'Roadside_Attractions']]}
# merged_dict: {'0': [['Super_Capers', 'distributor', 'Lionsgate'], ['Super_Capers', 'starring', 'Justin_Whalin'], ['Super_Capers', 'distributor', 'Roadside_Attractions']], '1': [['Roadside_Attractions', 'foundingYear', '2003-01-01']]}
# 1 ['Mexico currency Mexican_peso', 'Mexico demonym Mexicans', 'Bionico course Dessert', 'Bionico region Guadalajara', 'Mexico leader Silvano_Aureoles_Conejo', 'Bionico country Mexico', '']
# subject_dict: {'Mexico': [['Mexico', 'currency', 'Mexican_peso'], ['Mexico', 'demonym', 'Mexicans'], ['Mexico', 'leader', 'Silvano_Aureoles_Conejo']], 'Bionico': [['Bionico', 'course', 'Dessert'], ['Bionico', 'region', 'Guadalajara'], ['Bionico', 'country', 'Mexico']]}
# object_dict: {'Mexico': [['Bionico', 'country', 'Mexico'], ['Bionico', 'country', 'Mexico'], ['Bionico', 'country', 'Mexico']]}
# merged_dict: {'0': [['Mexico', 'currency', 'Mexican_peso'], ['Mexico', 'demonym', 'Mexicans'], ['Mexico', 'leader', 'Silvano_Aureoles_Conejo']], '1': [['Bionico', 'course', 'Dessert'], ['Bionico', 'region', 'Guadalajara'], ['Bionico', 'country', 'Mexico']]}
# 1 ['Estádio_Municipal_Coaracy_da_Mata_Fonseca location Arapiraca', 'Agremiação_Sportiva_Arapiraquense league Campeonato_Brasileiro_Série_C', 'Agremiação_Sportiva_Arapiraquense season 2015', 'Campeonato_Brasileiro_Série_C champions Vila_Nova_Futebol_Clube', 'Campeonato_Brasileiro_Série_C country Brazil', 'Agremiação_Sportiva_Arapiraquense numberOfMembers 17000', 'Agremiação_Sportiva_Arapiraquense ground Estádio_Municipal_Coaracy_da_Mata_Fonseca', '']
# subject_dict: {'Estádio_Municipal_Coaracy_da_Mata_Fonseca': [['Estádio_Municipal_Coaracy_da_Mata_Fonseca', 'location', 'Arapiraca']], 'Agremiação_Sportiva_Arapiraquense': [['Agremiação_Sportiva_Arapiraquense', 'league', 'Campeonato_Brasileiro_Série_C'], ['Agremiação_Sportiva_Arapiraquense', 'season', '2015'], ['Agremiação_Sportiva_Arapiraquense', 'numberOfMembers', '17000'], ['Agremiação_Sportiva_Arapiraquense', 'ground', 'Estádio_Municipal_Coaracy_da_Mata_Fonseca']], 'Campeonato_Brasileiro_Série_C': [['Campeonato_Brasileiro_Série_C', 'champions', 'Vila_Nova_Futebol_Clube'], ['Campeonato_Brasileiro_Série_C', 'country', 'Brazil']]}
# object_dict: {'Estádio_Municipal_Coaracy_da_Mata_Fonseca': [['Agremiação_Sportiva_Arapiraquense', 'ground', 'Estádio_Municipal_Coaracy_da_Mata_Fonseca']], 'Campeonato_Brasileiro_Série_C': [['Agremiação_Sportiva_Arapiraquense', 'league', 'Campeonato_Brasileiro_Série_C'], ['Agremiação_Sportiva_Arapiraquense', 'league', 'Campeonato_Brasileiro_Série_C']]}
# merged_dict: {'0': [['Estádio_Municipal_Coaracy_da_Mata_Fonseca', 'location', 'Arapiraca']], '1': [['Agremiação_Sportiva_Arapiraquense', 'league', 'Campeonato_Brasileiro_Série_C'], ['Agremiação_Sportiva_Arapiraquense', 'season', '2015'], ['Agremiação_Sportiva_Arapiraquense', 'numberOfMembers', '17000'], ['Agremiação_Sportiva_Arapiraquense', 'ground', 'Estádio_Municipal_Coaracy_da_Mata_Fonseca']], '2': [['Campeonato_Brasileiro_Série_C', 'champions', 'Vila_Nova_Futebol_Clube'], ['Campeonato_Brasileiro_Série_C', 'country', 'Brazil']]}
# 1 ['Acharya_Institute_of_Technology campus "In Soldevanahalli, Acharya Dr. Sarvapalli Radhakrishnan Road, Hessarghatta Main Road, Bangalore – 560090."', 'All_India_Council_for_Technical_Education location Mumbai', 'Acharya_Institute_of_Technology director "Dr. G. P. Prabhukumar"', 'Acharya_Institute_of_Technology established 2000', 'Acharya_Institute_of_Technology country "India"', 'Acharya_Institute_of_Technology wasGivenTheTechnicalCampusStatusBy All_India_Council_for_Technical_Education', '']
# subject_dict: {'Acharya_Institute_of_Technology': [['Acharya_Institute_of_Technology', 'campus', '"In', 'Soldevanahalli,', 'Acharya', 'Dr.', 'Sarvapalli', 'Radhakrishnan', 'Road,', 'Hessarghatta', 'Main', 'Road,', 'Bangalore', '–', '560090."'], ['Acharya_Institute_of_Technology', 'director', '"Dr.', 'G.', 'P.', 'Prabhukumar"'], ['Acharya_Institute_of_Technology', 'established', '2000'], ['Acharya_Institute_of_Technology', 'country', '"India"'], ['Acharya_Institute_of_Technology', 'wasGivenTheTechnicalCampusStatusBy', 'All_India_Council_for_Technical_Education']], 'All_India_Council_for_Technical_Education': [['All_India_Council_for_Technical_Education', 'location', 'Mumbai']]}
# object_dict: {'All_India_Council_for_Technical_Education': [['Acharya_Institute_of_Technology', 'wasGivenTheTechnicalCampusStatusBy', 'All_India_Council_for_Technical_Education']]}
# merged_dict: {'0': [['Acharya_Institute_of_Technology', 'campus', '"In', 'Soldevanahalli,', 'Acharya', 'Dr.', 'Sarvapalli', 'Radhakrishnan', 'Road,', 'Hessarghatta', 'Main', 'Road,', 'Bangalore', '–', '560090."'], ['Acharya_Institute_of_Technology', 'director', '"Dr.', 'G.', 'P.', 'Prabhukumar"'], ['Acharya_Institute_of_Technology', 'established', '2000'], ['Acharya_Institute_of_Technology', 'country', '"India"'], ['Acharya_Institute_of_Technology', 'wasGivenTheTechnicalCampusStatusBy', 'All_India_Council_for_Technical_Education']], '1': [['All_India_Council_for_Technical_Education', 'location', 'Mumbai']]}
# 1 ['Mexico currency Mexican_peso', 'Mexico demonym Mexicans', 'Bionico course Dessert', 'Bionico mainIngredient "Chopped Fruits, Sour Cream, Condensed Milk, Granola, Shredded Coconut, Raisins"', 'Dessert dishVariation Sandesh_(confectionery)', 'Bionico country Mexico', '']
# subject_dict: {'Mexico': [['Mexico', 'currency', 'Mexican_peso'], ['Mexico', 'demonym', 'Mexicans']], 'Bionico': [['Bionico', 'course', 'Dessert'], ['Bionico', 'mainIngredient', '"Chopped', 'Fruits,', 'Sour', 'Cream,', 'Condensed', 'Milk,', 'Granola,', 'Shredded', 'Coconut,', 'Raisins"'], ['Bionico', 'country', 'Mexico']], 'Dessert': [['Dessert', 'dishVariation', 'Sandesh_(confectionery)']]}
# object_dict: {'Mexico': [['Bionico', 'country', 'Mexico'], ['Bionico', 'country', 'Mexico']], 'Dessert': [['Bionico', 'course', 'Dessert']]}
# merged_dict: {'0': [['Mexico', 'currency', 'Mexican_peso'], ['Mexico', 'demonym', 'Mexicans']], '1': [['Bionico', 'course', 'Dessert'], ['Bionico', 'mainIngredient', '"Chopped', 'Fruits,', 'Sour', 'Cream,', 'Condensed', 'Milk,', 'Granola,', 'Shredded', 'Coconut,', 'Raisins"'], ['Bionico', 'country', 'Mexico']], '2': [['Dessert', 'dishVariation', 'Sandesh_(confectionery)']]}
# 1 ['Alan_Shepard deathPlace California', 'New_Hampshire bird Purple_finch', 'Alan_Shepard birthPlace New_Hampshire', '']
# subject_dict: {'Alan_Shepard': [['Alan_Shepard', 'deathPlace', 'California'], ['Alan_Shepard', 'birthPlace', 'New_Hampshire']], 'New_Hampshire': [['New_Hampshire', 'bird', 'Purple_finch']]}
# object_dict: {'New_Hampshire': [['Alan_Shepard', 'birthPlace', 'New_Hampshire']]}
# merged_dict: {'0': [['Alan_Shepard', 'deathPlace', 'California'], ['Alan_Shepard', 'birthPlace', 'New_Hampshire']], '1': [['New_Hampshire', 'bird', 'Purple_finch']]}
# 1 ['BBC city Broadcasting_House', 'Bananaman creator Steve_Bright', 'Bananaman broadcastedBy BBC', 'Bananaman starring Graeme_Garden', '']
# subject_dict: {'BBC': [['BBC', 'city', 'Broadcasting_House']], 'Bananaman': [['Bananaman', 'creator', 'Steve_Bright'], ['Bananaman', 'broadcastedBy', 'BBC'], ['Bananaman', 'starring', 'Graeme_Garden']]}
# object_dict: {'BBC': [['Bananaman', 'broadcastedBy', 'BBC']]}
# merged_dict: {'0': [['BBC', 'city', 'Broadcasting_House']], '1': [['Bananaman', 'creator', 'Steve_Bright'], ['Bananaman', 'broadcastedBy', 'BBC'], ['Bananaman', 'starring', 'Graeme_Garden']]}
# 1 ['Agremiação_Sportiva_Arapiraquense league Campeonato_Brasileiro_Série_C', 'Agremiação_Sportiva_Arapiraquense season 2015', 'Campeonato_Brasileiro_Série_C champions Vila_Nova_Futebol_Clube', 'Agremiação_Sportiva_Arapiraquense numberOfMembers 17000', '']
# subject_dict: {'Agremiação_Sportiva_Arapiraquense': [['Agremiação_Sportiva_Arapiraquense', 'league', 'Campeonato_Brasileiro_Série_C'], ['Agremiação_Sportiva_Arapiraquense', 'season', '2015'], ['Agremiação_Sportiva_Arapiraquense', 'numberOfMembers', '17000']], 'Campeonato_Brasileiro_Série_C': [['Campeonato_Brasileiro_Série_C', 'champions', 'Vila_Nova_Futebol_Clube']]}
# object_dict: {'Campeonato_Brasileiro_Série_C': [['Agremiação_Sportiva_Arapiraquense', 'league', 'Campeonato_Brasileiro_Série_C']]}
# merged_dict: {'0': [['Agremiação_Sportiva_Arapiraquense', 'league', 'Campeonato_Brasileiro_Série_C'], ['Agremiação_Sportiva_Arapiraquense', 'season', '2015'], ['Agremiação_Sportiva_Arapiraquense', 'numberOfMembers', '17000']], '1': [['Campeonato_Brasileiro_Série_C', 'champions', 'Vila_Nova_Futebol_Clube']]}
# 1 ['Bootleg_Series_Volume_1:_The_Quine_Tapes recordedIn San_Francisco', 'San_Francisco leader Ed_Lee_(politician)', 'Bootleg_Series_Volume_1:_The_Quine_Tapes recordedIn United_States', 'San_Francisco timeZone Pacific_Time_Zone', '']
# subject_dict: {'Bootleg_Series_Volume_1:_The_Quine_Tapes': [['Bootleg_Series_Volume_1:_The_Quine_Tapes', 'recordedIn', 'San_Francisco'], ['Bootleg_Series_Volume_1:_The_Quine_Tapes', 'recordedIn', 'United_States']], 'San_Francisco': [['San_Francisco', 'leader', 'Ed_Lee_(politician)'], ['San_Francisco', 'timeZone', 'Pacific_Time_Zone']]}
# object_dict: {'San_Francisco': [['Bootleg_Series_Volume_1:_The_Quine_Tapes', 'recordedIn', 'San_Francisco'], ['Bootleg_Series_Volume_1:_The_Quine_Tapes', 'recordedIn', 'San_Francisco']]}
# merged_dict: {'0': [['Bootleg_Series_Volume_1:_The_Quine_Tapes', 'recordedIn', 'San_Francisco'], ['Bootleg_Series_Volume_1:_The_Quine_Tapes', 'recordedIn', 'United_States']], '1': [['San_Francisco', 'leader', 'Ed_Lee_(politician)'], ['San_Francisco', 'timeZone', 'Pacific_Time_Zone']]}
# 1 ['BBC city Broadcasting_House', 'Bananaman starring Bill_Oddie', 'Bananaman creator John_Geering', 'Bananaman broadcastedBy BBC', 'Bananaman firstAired "1983-10-03"', '']
# subject_dict: {'BBC': [['BBC', 'city', 'Broadcasting_House']], 'Bananaman': [['Bananaman', 'starring', 'Bill_Oddie'], ['Bananaman', 'creator', 'John_Geering'], ['Bananaman', 'broadcastedBy', 'BBC'], ['Bananaman', 'firstAired', '"1983-10-03"']]}
# object_dict: {'BBC': [['Bananaman', 'broadcastedBy', 'BBC']]}
# merged_dict: {'0': [['BBC', 'city', 'Broadcasting_House']], '1': [['Bananaman', 'starring', 'Bill_Oddie'], ['Bananaman', 'creator', 'John_Geering'], ['Bananaman', 'broadcastedBy', 'BBC'], ['Bananaman', 'firstAired', '"1983-10-03"']]}
# 1 ['Liselotte_Grschebina deathPlace Israel', 'Petah_Tikva meaning "Opening of hope"', 'Israel longName "State of Israel"', 'Liselotte_Grschebina deathPlace Petah_Tikva', '']
# subject_dict: {'Liselotte_Grschebina': [['Liselotte_Grschebina', 'deathPlace', 'Israel'], ['Liselotte_Grschebina', 'deathPlace', 'Petah_Tikva']], 'Petah_Tikva': [['Petah_Tikva', 'meaning', '"Opening', 'of', 'hope"']], 'Israel': [['Israel', 'longName', '"State', 'of', 'Israel"']]}
# object_dict: {'Petah_Tikva': [['Liselotte_Grschebina', 'deathPlace', 'Petah_Tikva']], 'Israel': [['Liselotte_Grschebina', 'deathPlace', 'Israel']]}
# merged_dict: {'0': [['Liselotte_Grschebina', 'deathPlace', 'Israel'], ['Liselotte_Grschebina', 'deathPlace', 'Petah_Tikva']], '1': [['Petah_Tikva', 'meaning', '"Opening', 'of', 'hope"']], '2': [['Israel', 'longName', '"State', 'of', 'Israel"']]}
# 1 ['Adolfo_Suárez_Madrid–Barajas_Airport operatingOrganisation ENAIRE', 'Adolfo_Suárez_Madrid–Barajas_Airport location Alcobendas', 'ENAIRE city Madrid', 'Adolfo_Suárez_Madrid–Barajas_Airport elevationAboveTheSeaLevel 610.0', '']
# subject_dict: {'Adolfo_Suárez_Madrid–Barajas_Airport': [['Adolfo_Suárez_Madrid–Barajas_Airport', 'operatingOrganisation', 'ENAIRE'], ['Adolfo_Suárez_Madrid–Barajas_Airport', 'location', 'Alcobendas'], ['Adolfo_Suárez_Madrid–Barajas_Airport', 'elevationAboveTheSeaLevel', '610.0']], 'ENAIRE': [['ENAIRE', 'city', 'Madrid']]}
# object_dict: {'ENAIRE': [['Adolfo_Suárez_Madrid–Barajas_Airport', 'operatingOrganisation', 'ENAIRE']]}
# merged_dict: {'0': [['Adolfo_Suárez_Madrid–Barajas_Airport', 'operatingOrganisation', 'ENAIRE'], ['Adolfo_Suárez_Madrid–Barajas_Airport', 'location', 'Alcobendas'], ['Adolfo_Suárez_Madrid–Barajas_Airport', 'elevationAboveTheSeaLevel', '610.0']], '1': [['ENAIRE', 'city', 'Madrid']]}
# 1 ['Chinabank location Philippines', 'Philippines timeZone Philippine_Standard_Time', 'Chinabank foundingDate 1920-08-16', '']
# subject_dict: {'Chinabank': [['Chinabank', 'location', 'Philippines'], ['Chinabank', 'foundingDate', '1920-08-16']], 'Philippines': [['Philippines', 'timeZone', 'Philippine_Standard_Time']]}
# object_dict: {'Philippines': [['Chinabank', 'location', 'Philippines']]}
# merged_dict: {'0': [['Chinabank', 'location', 'Philippines'], ['Chinabank', 'foundingDate', '1920-08-16']], '1': [['Philippines', 'timeZone', 'Philippine_Standard_Time']]}
# 1 ["It's_Great_to_Be_Young_(1956_film) editing Max_Benedict", 'Max_Benedict deathYear 1986', "It's_Great_to_Be_Young_(1956_film) director Cyril_Frankel", "It's_Great_to_Be_Young_(1956_film) musicComposer Louis_Levy", '']
# subject_dict: {"It's_Great_to_Be_Young_(1956_film)": [["It's_Great_to_Be_Young_(1956_film)", 'editing', 'Max_Benedict'], ["It's_Great_to_Be_Young_(1956_film)", 'director', 'Cyril_Frankel'], ["It's_Great_to_Be_Young_(1956_film)", 'musicComposer', 'Louis_Levy']], 'Max_Benedict': [['Max_Benedict', 'deathYear', '1986']]}
# object_dict: {'Max_Benedict': [["It's_Great_to_Be_Young_(1956_film)", 'editing', 'Max_Benedict']]}
# merged_dict: {'0': [["It's_Great_to_Be_Young_(1956_film)", 'editing', 'Max_Benedict'], ["It's_Great_to_Be_Young_(1956_film)", 'director', 'Cyril_Frankel'], ["It's_Great_to_Be_Young_(1956_film)", 'musicComposer', 'Louis_Levy']], '1': [['Max_Benedict', 'deathYear', '1986']]}
# 1 ['Darlington areaCode 01325', 'Lady_Anne_Monson birthPlace Kingdom_of_England', 'Lady_Anne_Monson birthPlace Darlington', 'Darlington postalCode "DL1, DL2, DL3"', '']
# subject_dict: {'Darlington': [['Darlington', 'areaCode', '01325'], ['Darlington', 'postalCode', '"DL1,', 'DL2,', 'DL3"']], 'Lady_Anne_Monson': [['Lady_Anne_Monson', 'birthPlace', 'Kingdom_of_England'], ['Lady_Anne_Monson', 'birthPlace', 'Darlington']]}
# object_dict: {'Darlington': [['Lady_Anne_Monson', 'birthPlace', 'Darlington'], ['Lady_Anne_Monson', 'birthPlace', 'Darlington']]}
# merged_dict: {'0': [['Darlington', 'areaCode', '01325'], ['Darlington', 'postalCode', '"DL1,', 'DL2,', 'DL3"']], '1': [['Lady_Anne_Monson', 'birthPlace', 'Kingdom_of_England'], ['Lady_Anne_Monson', 'birthPlace', 'Darlington']]}
# 1 ['Adams_County,_Pennsylvania hasToItsWest Franklin_County,_Pennsylvania', '11th_Mississippi_Infantry_Monument established 2000', '11th_Mississippi_Infantry_Monument location Adams_County,_Pennsylvania', '11th_Mississippi_Infantry_Monument municipality Gettysburg,_Pennsylvania', 'Adams_County,_Pennsylvania hasToItsSoutheast Carroll_County,_Maryland', '11th_Mississippi_Infantry_Monument category Contributing_property', '']
# subject_dict: {'Adams_County,_Pennsylvania': [['Adams_County,_Pennsylvania', 'hasToItsWest', 'Franklin_County,_Pennsylvania'], ['Adams_County,_Pennsylvania', 'hasToItsSoutheast', 'Carroll_County,_Maryland']], '11th_Mississippi_Infantry_Monument': [['11th_Mississippi_Infantry_Monument', 'established', '2000'], ['11th_Mississippi_Infantry_Monument', 'location', 'Adams_County,_Pennsylvania'], ['11th_Mississippi_Infantry_Monument', 'municipality', 'Gettysburg,_Pennsylvania'], ['11th_Mississippi_Infantry_Monument', 'category', 'Contributing_property']]}
# object_dict: {'Adams_County,_Pennsylvania': [['11th_Mississippi_Infantry_Monument', 'location', 'Adams_County,_Pennsylvania'], ['11th_Mississippi_Infantry_Monument', 'location', 'Adams_County,_Pennsylvania']]}
# merged_dict: {'0': [['Adams_County,_Pennsylvania', 'hasToItsWest', 'Franklin_County,_Pennsylvania'], ['Adams_County,_Pennsylvania', 'hasToItsSoutheast', 'Carroll_County,_Maryland']], '1': [['11th_Mississippi_Infantry_Monument', 'established', '2000'], ['11th_Mississippi_Infantry_Monument', 'location', 'Adams_County,_Pennsylvania'], ['11th_Mississippi_Infantry_Monument', 'municipality', 'Gettysburg,_Pennsylvania'], ['11th_Mississippi_Infantry_Monument', 'category', 'Contributing_property']]}
# 1 ['Lady_Anne_Monson birthPlace Darlington', 'Darlington country United_Kingdom', 'Lady_Anne_Monson birthPlace Kingdom_of_England', '']
# subject_dict: {'Lady_Anne_Monson': [['Lady_Anne_Monson', 'birthPlace', 'Darlington'], ['Lady_Anne_Monson', 'birthPlace', 'Kingdom_of_England']], 'Darlington': [['Darlington', 'country', 'United_Kingdom']]}
# object_dict: {'Darlington': [['Lady_Anne_Monson', 'birthPlace', 'Darlington']]}
# merged_dict: {'0': [['Lady_Anne_Monson', 'birthPlace', 'Darlington'], ['Lady_Anne_Monson', 'birthPlace', 'Kingdom_of_England']], '1': [['Darlington', 'country', 'United_Kingdom']]}
# 1 ['English_Without_Tears writer Anatole_de_Grunwald', 'Terence_Rattigan deathPlace Hamilton,_Bermuda', 'Anatole_de_Grunwald deathPlace London', 'English_Without_Tears writer Terence_Rattigan', '']
# subject_dict: {'English_Without_Tears': [['English_Without_Tears', 'writer', 'Anatole_de_Grunwald'], ['English_Without_Tears', 'writer', 'Terence_Rattigan']], 'Terence_Rattigan': [['Terence_Rattigan', 'deathPlace', 'Hamilton,_Bermuda']], 'Anatole_de_Grunwald': [['Anatole_de_Grunwald', 'deathPlace', 'London']]}
# object_dict: {'Terence_Rattigan': [['English_Without_Tears', 'writer', 'Terence_Rattigan']], 'Anatole_de_Grunwald': [['English_Without_Tears', 'writer', 'Anatole_de_Grunwald']]}
# merged_dict: {'0': [['English_Without_Tears', 'writer', 'Anatole_de_Grunwald'], ['English_Without_Tears', 'writer', 'Terence_Rattigan']], '1': [['Terence_Rattigan', 'deathPlace', 'Hamilton,_Bermuda']], '2': [['Anatole_de_Grunwald', 'deathPlace', 'London']]}
# 1 ['Adolfo_Suárez_Madrid–Barajas_Airport operatingOrganisation ENAIRE', 'Adolfo_Suárez_Madrid–Barajas_Airport location Alcobendas', 'ENAIRE city Madrid', 'Adolfo_Suárez_Madrid–Barajas_Airport runwayLength 3500.0', 'Adolfo_Suárez_Madrid–Barajas_Airport elevationAboveTheSeaLevel 610.0', '']
# subject_dict: {'Adolfo_Suárez_Madrid–Barajas_Airport': [['Adolfo_Suárez_Madrid–Barajas_Airport', 'operatingOrganisation', 'ENAIRE'], ['Adolfo_Suárez_Madrid–Barajas_Airport', 'location', 'Alcobendas'], ['Adolfo_Suárez_Madrid–Barajas_Airport', 'runwayLength', '3500.0'], ['Adolfo_Suárez_Madrid–Barajas_Airport', 'elevationAboveTheSeaLevel', '610.0']], 'ENAIRE': [['ENAIRE', 'city', 'Madrid']]}
# object_dict: {'ENAIRE': [['Adolfo_Suárez_Madrid–Barajas_Airport', 'operatingOrganisation', 'ENAIRE']]}
# merged_dict: {'0': [['Adolfo_Suárez_Madrid–Barajas_Airport', 'operatingOrganisation', 'ENAIRE'], ['Adolfo_Suárez_Madrid–Barajas_Airport', 'location', 'Alcobendas'], ['Adolfo_Suárez_Madrid–Barajas_Airport', 'runwayLength', '3500.0'], ['Adolfo_Suárez_Madrid–Barajas_Airport', 'elevationAboveTheSeaLevel', '610.0']], '1': [['ENAIRE', 'city', 'Madrid']]}
# 1 ['BBC city Broadcasting_House', 'Bananaman creator Steve_Bright', 'Bananaman lastAired "1986-04-15"', 'Bananaman broadcastedBy BBC', '']
# subject_dict: {'BBC': [['BBC', 'city', 'Broadcasting_House']], 'Bananaman': [['Bananaman', 'creator', 'Steve_Bright'], ['Bananaman', 'lastAired', '"1986-04-15"'], ['Bananaman', 'broadcastedBy', 'BBC']]}
# object_dict: {'BBC': [['Bananaman', 'broadcastedBy', 'BBC']]}
# merged_dict: {'0': [['BBC', 'city', 'Broadcasting_House']], '1': [['Bananaman', 'creator', 'Steve_Bright'], ['Bananaman', 'lastAired', '"1986-04-15"'], ['Bananaman', 'broadcastedBy', 'BBC']]}
# 1 ['Abraham_A._Ribicoff spouse "Ruth Ribicoff"', 'Abraham_A._Ribicoff successor John_N._Dempsey', 'Abraham_A._Ribicoff birthPlace United_States', 'United_States ethnicGroup African_Americans', '']
# subject_dict: {'Abraham_A._Ribicoff': [['Abraham_A._Ribicoff', 'spouse', '"Ruth', 'Ribicoff"'], ['Abraham_A._Ribicoff', 'successor', 'John_N._Dempsey'], ['Abraham_A._Ribicoff', 'birthPlace', 'United_States']], 'United_States': [['United_States', 'ethnicGroup', 'African_Americans']]}
# object_dict: {'United_States': [['Abraham_A._Ribicoff', 'birthPlace', 'United_States']]}
# merged_dict: {'0': [['Abraham_A._Ribicoff', 'spouse', '"Ruth', 'Ribicoff"'], ['Abraham_A._Ribicoff', 'successor', 'John_N._Dempsey'], ['Abraham_A._Ribicoff', 'birthPlace', 'United_States']], '1': [['United_States', 'ethnicGroup', 'African_Americans']]}
# 1 ['Lady_Anne_Monson birthPlace Darlington', 'India longName "Republic of India"', 'Lady_Anne_Monson birthPlace Kingdom_of_England', 'Darlington populationTotal 106000', 'Lady_Anne_Monson residence India', '']
# subject_dict: {'Lady_Anne_Monson': [['Lady_Anne_Monson', 'birthPlace', 'Darlington'], ['Lady_Anne_Monson', 'birthPlace', 'Kingdom_of_England'], ['Lady_Anne_Monson', 'residence', 'India']], 'India': [['India', 'longName', '"Republic', 'of', 'India"']], 'Darlington': [['Darlington', 'populationTotal', '106000']]}
# object_dict: {'India': [['Lady_Anne_Monson', 'residence', 'India']], 'Darlington': [['Lady_Anne_Monson', 'birthPlace', 'Darlington']]}
# merged_dict: {'0': [['Lady_Anne_Monson', 'birthPlace', 'Darlington'], ['Lady_Anne_Monson', 'birthPlace', 'Kingdom_of_England'], ['Lady_Anne_Monson', 'residence', 'India']], '1': [['India', 'longName', '"Republic', 'of', 'India"']], '2': [['Darlington', 'populationTotal', '106000']]}
# 1 ['AmeriGas city King_of_Prussia,_Pennsylvania', 'United_States populationTotal 324720797', 'AmeriGas country United_States', 'AmeriGas regionServed United_States', 'United_States areaTotal 9833516.63  (square kilometres)', '']
# subject_dict: {'AmeriGas': [['AmeriGas', 'city', 'King_of_Prussia,_Pennsylvania'], ['AmeriGas', 'country', 'United_States'], ['AmeriGas', 'regionServed', 'United_States']], 'United_States': [['United_States', 'populationTotal', '324720797'], ['United_States', 'areaTotal', '9833516.63', '', '(square', 'kilometres)']]}
# object_dict: {'United_States': [['AmeriGas', 'country', 'United_States'], ['AmeriGas', 'regionServed', 'United_States'], ['AmeriGas', 'country', 'United_States'], ['AmeriGas', 'regionServed', 'United_States']]}
# merged_dict: {'0': [['AmeriGas', 'city', 'King_of_Prussia,_Pennsylvania'], ['AmeriGas', 'country', 'United_States'], ['AmeriGas', 'regionServed', 'United_States']], '1': [['United_States', 'populationTotal', '324720797'], ['United_States', 'areaTotal', '9833516.63', '', '(square', 'kilometres)']]}
# 1 ['Bootleg_Series_Volume_1:_The_Quine_Tapes precededBy Squeeze_(The_Velvet_Underground_album)', 'Bootleg_Series_Volume_1:_The_Quine_Tapes releaseDate 2001-10-16', "Squeeze_(The_Velvet_Underground_album) precededBy Andy_Warhol's_Velvet_Underground_Featuring_Nico", '']
# subject_dict: {'Bootleg_Series_Volume_1:_The_Quine_Tapes': [['Bootleg_Series_Volume_1:_The_Quine_Tapes', 'precededBy', 'Squeeze_(The_Velvet_Underground_album)'], ['Bootleg_Series_Volume_1:_The_Quine_Tapes', 'releaseDate', '2001-10-16']], 'Squeeze_(The_Velvet_Underground_album)': [['Squeeze_(The_Velvet_Underground_album)', 'precededBy', "Andy_Warhol's_Velvet_Underground_Featuring_Nico"]]}
# object_dict: {'Squeeze_(The_Velvet_Underground_album)': [['Bootleg_Series_Volume_1:_The_Quine_Tapes', 'precededBy', 'Squeeze_(The_Velvet_Underground_album)']]}
# merged_dict: {'0': [['Bootleg_Series_Volume_1:_The_Quine_Tapes', 'precededBy', 'Squeeze_(The_Velvet_Underground_album)'], ['Bootleg_Series_Volume_1:_The_Quine_Tapes', 'releaseDate', '2001-10-16']], '1': [['Squeeze_(The_Velvet_Underground_album)', 'precededBy', "Andy_Warhol's_Velvet_Underground_Featuring_Nico"]]}
# 1 ['1147_Stavropolis discoverer Grigory_Neujmin', '1147_Stavropolis periapsis 260855000000.0', '1147_Stavropolis orbitalPeriod 1249.6', 'Grigory_Neujmin birthPlace Tbilisi', 'Grigory_Neujmin birthDate 1886-01-01', '']
# subject_dict: {'1147_Stavropolis': [['1147_Stavropolis', 'discoverer', 'Grigory_Neujmin'], ['1147_Stavropolis', 'periapsis', '260855000000.0'], ['1147_Stavropolis', 'orbitalPeriod', '1249.6']], 'Grigory_Neujmin': [['Grigory_Neujmin', 'birthPlace', 'Tbilisi'], ['Grigory_Neujmin', 'birthDate', '1886-01-01']]}
# object_dict: {'Grigory_Neujmin': [['1147_Stavropolis', 'discoverer', 'Grigory_Neujmin'], ['1147_Stavropolis', 'discoverer', 'Grigory_Neujmin']]}
# merged_dict: {'0': [['1147_Stavropolis', 'discoverer', 'Grigory_Neujmin'], ['1147_Stavropolis', 'periapsis', '260855000000.0'], ['1147_Stavropolis', 'orbitalPeriod', '1249.6']], '1': [['Grigory_Neujmin', 'birthPlace', 'Tbilisi'], ['Grigory_Neujmin', 'birthDate', '1886-01-01']]}
# 1 ['BBC city Broadcasting_House', 'Bananaman starring Bill_Oddie', 'Bananaman creator Steve_Bright', 'Bill_Oddie birthPlace Rochdale', 'Bananaman broadcastedBy BBC', '']
# subject_dict: {'BBC': [['BBC', 'city', 'Broadcasting_House']], 'Bananaman': [['Bananaman', 'starring', 'Bill_Oddie'], ['Bananaman', 'creator', 'Steve_Bright'], ['Bananaman', 'broadcastedBy', 'BBC']], 'Bill_Oddie': [['Bill_Oddie', 'birthPlace', 'Rochdale']]}
# object_dict: {'BBC': [['Bananaman', 'broadcastedBy', 'BBC']], 'Bill_Oddie': [['Bananaman', 'starring', 'Bill_Oddie']]}
# merged_dict: {'0': [['BBC', 'city', 'Broadcasting_House']], '1': [['Bananaman', 'starring', 'Bill_Oddie'], ['Bananaman', 'creator', 'Steve_Bright'], ['Bananaman', 'broadcastedBy', 'BBC']], '2': [['Bill_Oddie', 'birthPlace', 'Rochdale']]}
# 1 ['Agremiação_Sportiva_Arapiraquense league Campeonato_Brasileiro_Série_C', 'Campeonato_Brasileiro_Série_C champions Vila_Nova_Futebol_Clube', 'Agremiação_Sportiva_Arapiraquense numberOfMembers 17000', 'Agremiação_Sportiva_Arapiraquense fullName "Agremiação Sportiva Arapiraquense"', '']
# subject_dict: {'Agremiação_Sportiva_Arapiraquense': [['Agremiação_Sportiva_Arapiraquense', 'league', 'Campeonato_Brasileiro_Série_C'], ['Agremiação_Sportiva_Arapiraquense', 'numberOfMembers', '17000'], ['Agremiação_Sportiva_Arapiraquense', 'fullName', '"Agremiação', 'Sportiva', 'Arapiraquense"']], 'Campeonato_Brasileiro_Série_C': [['Campeonato_Brasileiro_Série_C', 'champions', 'Vila_Nova_Futebol_Clube']]}
# object_dict: {'Campeonato_Brasileiro_Série_C': [['Agremiação_Sportiva_Arapiraquense', 'league', 'Campeonato_Brasileiro_Série_C']]}
# merged_dict: {'0': [['Agremiação_Sportiva_Arapiraquense', 'league', 'Campeonato_Brasileiro_Série_C'], ['Agremiação_Sportiva_Arapiraquense', 'numberOfMembers', '17000'], ['Agremiação_Sportiva_Arapiraquense', 'fullName', '"Agremiação', 'Sportiva', 'Arapiraquense"']], '1': [['Campeonato_Brasileiro_Série_C', 'champions', 'Vila_Nova_Futebol_Clube']]}
# 1 ['Pontiac_Rageous manufacturer Pontiac', 'Pontiac parentCompany General_Motors', 'Pontiac_Rageous assembly Michigan', 'Pontiac_Rageous assembly Detroit', '']
# subject_dict: {'Pontiac_Rageous': [['Pontiac_Rageous', 'manufacturer', 'Pontiac'], ['Pontiac_Rageous', 'assembly', 'Michigan'], ['Pontiac_Rageous', 'assembly', 'Detroit']], 'Pontiac': [['Pontiac', 'parentCompany', 'General_Motors']]}
# object_dict: {'Pontiac': [['Pontiac_Rageous', 'manufacturer', 'Pontiac']]}
# merged_dict: {'0': [['Pontiac_Rageous', 'manufacturer', 'Pontiac'], ['Pontiac_Rageous', 'assembly', 'Michigan'], ['Pontiac_Rageous', 'assembly', 'Detroit']], '1': [['Pontiac', 'parentCompany', 'General_Motors']]}
# 1 ['Acharya_Institute_of_Technology campus "In Soldevanahalli, Acharya Dr. Sarvapalli Radhakrishnan Road, Hessarghatta Main Road, Bangalore – 560090."', 'All_India_Council_for_Technical_Education location Mumbai', 'Acharya_Institute_of_Technology director "Dr. G. P. Prabhukumar"', 'Acharya_Institute_of_Technology affiliation Visvesvaraya_Technological_University', 'Acharya_Institute_of_Technology wasGivenTheTechnicalCampusStatusBy All_India_Council_for_Technical_Education', 'Acharya_Institute_of_Technology state Karnataka', '']
# subject_dict: {'Acharya_Institute_of_Technology': [['Acharya_Institute_of_Technology', 'campus', '"In', 'Soldevanahalli,', 'Acharya', 'Dr.', 'Sarvapalli', 'Radhakrishnan', 'Road,', 'Hessarghatta', 'Main', 'Road,', 'Bangalore', '–', '560090."'], ['Acharya_Institute_of_Technology', 'director', '"Dr.', 'G.', 'P.', 'Prabhukumar"'], ['Acharya_Institute_of_Technology', 'affiliation', 'Visvesvaraya_Technological_University'], ['Acharya_Institute_of_Technology', 'wasGivenTheTechnicalCampusStatusBy', 'All_India_Council_for_Technical_Education'], ['Acharya_Institute_of_Technology', 'state', 'Karnataka']], 'All_India_Council_for_Technical_Education': [['All_India_Council_for_Technical_Education', 'location', 'Mumbai']]}
# object_dict: {'All_India_Council_for_Technical_Education': [['Acharya_Institute_of_Technology', 'wasGivenTheTechnicalCampusStatusBy', 'All_India_Council_for_Technical_Education']]}
# merged_dict: {'0': [['Acharya_Institute_of_Technology', 'campus', '"In', 'Soldevanahalli,', 'Acharya', 'Dr.', 'Sarvapalli', 'Radhakrishnan', 'Road,', 'Hessarghatta', 'Main', 'Road,', 'Bangalore', '–', '560090."'], ['Acharya_Institute_of_Technology', 'director', '"Dr.', 'G.', 'P.', 'Prabhukumar"'], ['Acharya_Institute_of_Technology', 'affiliation', 'Visvesvaraya_Technological_University'], ['Acharya_Institute_of_Technology', 'wasGivenTheTechnicalCampusStatusBy', 'All_India_Council_for_Technical_Education'], ['Acharya_Institute_of_Technology', 'state', 'Karnataka']], '1': [['All_India_Council_for_Technical_Education', 'location', 'Mumbai']]}
# 1 ['Bionico course Dessert', 'Dessert dishVariation Sandesh_(confectionery)', 'Bionico country Mexico', '']
# subject_dict: {'Bionico': [['Bionico', 'course', 'Dessert'], ['Bionico', 'country', 'Mexico']], 'Dessert': [['Dessert', 'dishVariation', 'Sandesh_(confectionery)']]}
# object_dict: {'Dessert': [['Bionico', 'course', 'Dessert']]}
# merged_dict: {'0': [['Bionico', 'course', 'Dessert'], ['Bionico', 'country', 'Mexico']], '1': [['Dessert', 'dishVariation', 'Sandesh_(confectionery)']]}
# 1 ['Estádio_Municipal_Coaracy_da_Mata_Fonseca location Arapiraca', 'Agremiação_Sportiva_Arapiraquense league Campeonato_Brasileiro_Série_C', 'Campeonato_Brasileiro_Série_C champions Vila_Nova_Futebol_Clube', 'Campeonato_Brasileiro_Série_C country Brazil', 'Agremiação_Sportiva_Arapiraquense ground Estádio_Municipal_Coaracy_da_Mata_Fonseca', 'Agremiação_Sportiva_Arapiraquense fullName "Agremiação Sportiva Arapiraquense"', '']
# subject_dict: {'Estádio_Municipal_Coaracy_da_Mata_Fonseca': [['Estádio_Municipal_Coaracy_da_Mata_Fonseca', 'location', 'Arapiraca']], 'Agremiação_Sportiva_Arapiraquense': [['Agremiação_Sportiva_Arapiraquense', 'league', 'Campeonato_Brasileiro_Série_C'], ['Agremiação_Sportiva_Arapiraquense', 'ground', 'Estádio_Municipal_Coaracy_da_Mata_Fonseca'], ['Agremiação_Sportiva_Arapiraquense', 'fullName', '"Agremiação', 'Sportiva', 'Arapiraquense"']], 'Campeonato_Brasileiro_Série_C': [['Campeonato_Brasileiro_Série_C', 'champions', 'Vila_Nova_Futebol_Clube'], ['Campeonato_Brasileiro_Série_C', 'country', 'Brazil']]}
# object_dict: {'Estádio_Municipal_Coaracy_da_Mata_Fonseca': [['Agremiação_Sportiva_Arapiraquense', 'ground', 'Estádio_Municipal_Coaracy_da_Mata_Fonseca']], 'Campeonato_Brasileiro_Série_C': [['Agremiação_Sportiva_Arapiraquense', 'league', 'Campeonato_Brasileiro_Série_C'], ['Agremiação_Sportiva_Arapiraquense', 'league', 'Campeonato_Brasileiro_Série_C']]}
# ...
# 1 ['Mexico currency Mexican_peso', 'Mexico demonym Mexicans', 'Bionico ingredient Granola', 'Bionico region Jalisco', 'Bionico country Mexico', '']
# subject_dict: {'Mexico': [['Mexico', 'currency', 'Mexican_peso'], ['Mexico', 'demonym', 'Mexicans']], 'Bionico': [['Bionico', 'ingredient', 'Granola'], ['Bionico', 'region', 'Jalisco'], ['Bionico', 'country', 'Mexico']]}
# object_dict: {'Mexico': [['Bionico', 'country', 'Mexico'], ['Bionico', 'country', 'Mexico']]}
# merged_dict: {'0': [['Mexico', 'currency', 'Mexican_peso'], ['Mexico', 'demonym', 'Mexicans']], '1': [['Bionico', 'ingredient', 'Granola'], ['Bionico', 'region', 'Jalisco'], ['Bionico', 'country', 'Mexico']]}
# 1 ['Mexico currency Mexican_peso', 'Bionico course Dessert', 'Mexico leader Silvano_Aureoles_Conejo', 'Bionico country Mexico', '']
# subject_dict: {'Mexico': [['Mexico', 'currency', 'Mexican_peso'], ['Mexico', 'leader', 'Silvano_Aureoles_Conejo']], 'Bionico': [['Bionico', 'course', 'Dessert'], ['Bionico', 'country', 'Mexico']]}
# object_dict: {'Mexico': [['Bionico', 'country', 'Mexico'], ['Bionico', 'country', 'Mexico']]}
# merged_dict: {'0': [['Mexico', 'currency', 'Mexican_peso'], ['Mexico', 'leader', 'Silvano_Aureoles_Conejo']], '1': [['Bionico', 'course', 'Dessert'], ['Bionico', 'country', 'Mexico']]}
# 1 ['Alan_B._Miller_Hall currentTenants Mason_School_of_Business', 'Mason_School_of_Business country United_States', 'Alan_B._Miller_Hall owner College_of_William_&_Mary', '']
# subject_dict: {'Alan_B._Miller_Hall': [['Alan_B._Miller_Hall', 'currentTenants', 'Mason_School_of_Business'], ['Alan_B._Miller_Hall', 'owner', 'College_of_William_&_Mary']], 'Mason_School_of_Business': [['Mason_School_of_Business', 'country', 'United_States']]}
# object_dict: {'Mason_School_of_Business': [['Alan_B._Miller_Hall', 'currentTenants', 'Mason_School_of_Business']]}
# merged_dict: {'0': [['Alan_B._Miller_Hall', 'currentTenants', 'Mason_School_of_Business'], ['Alan_B._Miller_Hall', 'owner', 'College_of_William_&_Mary']], '1': [['Mason_School_of_Business', 'country', 'United_States']]}
# 1 ['BBC city Broadcasting_House', 'Bananaman starring Bill_Oddie', 'Bananaman creator Steve_Bright', 'Bananaman broadcastedBy BBC', '']
# subject_dict: {'BBC': [['BBC', 'city', 'Broadcasting_House']], 'Bananaman': [['Bananaman', 'starring', 'Bill_Oddie'], ['Bananaman', 'creator', 'Steve_Bright'], ['Bananaman', 'broadcastedBy', 'BBC']]}
# object_dict: {'BBC': [['Bananaman', 'broadcastedBy', 'BBC']]}
# merged_dict: {'0': [['BBC', 'city', 'Broadcasting_House']], '1': [['Bananaman', 'starring', 'Bill_Oddie'], ['Bananaman', 'creator', 'Steve_Bright'], ['Bananaman', 'broadcastedBy', 'BBC']]}
# 1 ['11th_Mississippi_Infantry_Monument location Adams_County,_Pennsylvania', '11th_Mississippi_Infantry_Monument municipality Gettysburg,_Pennsylvania', 'Adams_County,_Pennsylvania hasToItsSoutheast Carroll_County,_Maryland', '11th_Mississippi_Infantry_Monument category Contributing_property', '']
# subject_dict: {'11th_Mississippi_Infantry_Monument': [['11th_Mississippi_Infantry_Monument', 'location', 'Adams_County,_Pennsylvania'], ['11th_Mississippi_Infantry_Monument', 'municipality', 'Gettysburg,_Pennsylvania'], ['11th_Mississippi_Infantry_Monument', 'category', 'Contributing_property']], 'Adams_County,_Pennsylvania': [['Adams_County,_Pennsylvania', 'hasToItsSoutheast', 'Carroll_County,_Maryland']]}
# object_dict: {'Adams_County,_Pennsylvania': [['11th_Mississippi_Infantry_Monument', 'location', 'Adams_County,_Pennsylvania']]}
# merged_dict: {'0': [['11th_Mississippi_Infantry_Monument', 'location', 'Adams_County,_Pennsylvania'], ['11th_Mississippi_Infantry_Monument', 'municipality', 'Gettysburg,_Pennsylvania'], ['11th_Mississippi_Infantry_Monument', 'category', 'Contributing_property']], '1': [['Adams_County,_Pennsylvania', 'hasToItsSoutheast', 'Carroll_County,_Maryland']]}
# 1 ['11th_Mississippi_Infantry_Monument location Adams_County,_Pennsylvania', '11th_Mississippi_Infantry_Monument municipality Gettysburg,_Pennsylvania', 'Adams_County,_Pennsylvania hasToItsSoutheast Carroll_County,_Maryland', '11th_Mississippi_Infantry_Monument category Contributing_property', '']
# subject_dict: {'11th_Mississippi_Infantry_Monument': [['11th_Mississippi_Infantry_Monument', 'location', 'Adams_County,_Pennsylvania'], ['11th_Mississippi_Infantry_Monument', 'municipality', 'Gettysburg,_Pennsylvania'], ['11th_Mississippi_Infantry_Monument', 'category', 'Contributing_property']], 'Adams_County,_Pennsylvania': [['Adams_County,_Pennsylvania', 'hasToItsSoutheast', 'Carroll_County,_Maryland']]}
# object_dict: {'Adams_County,_Pennsylvania': [['11th_Mississippi_Infantry_Monument', 'location', 'Adams_County,_Pennsylvania']]}
# merged_dict: {'0': [['11th_Mississippi_Infantry_Monument', 'location', 'Adams_County,_Pennsylvania'], ['11th_Mississippi_Infantry_Monument', 'municipality', 'Gettysburg,_Pennsylvania'], ['11th_Mississippi_Infantry_Monument', 'category', 'Contributing_property']], '1': [['Adams_County,_Pennsylvania', 'hasToItsSoutheast', 'Carroll_County,_Maryland']]}
# 1 ['Nurhan_Atasoy residence Istanbul', 'Turkey capital Ankara', 'Nurhan_Atasoy residence Turkey', 'Nurhan_Atasoy nationality Turkish_people', 'Turkish_people religion Irreligion', '']
# subject_dict: {'Nurhan_Atasoy': [['Nurhan_Atasoy', 'residence', 'Istanbul'], ['Nurhan_Atasoy', 'residence', 'Turkey'], ['Nurhan_Atasoy', 'nationality', 'Turkish_people']], 'Turkey': [['Turkey', 'capital', 'Ankara']], 'Turkish_people': [['Turkish_people', 'religion', 'Irreligion']]}
# object_dict: {'Turkey': [['Nurhan_Atasoy', 'residence', 'Turkey']], 'Turkish_people': [['Nurhan_Atasoy', 'nationality', 'Turkish_people']]}
# merged_dict: {'0': [['Nurhan_Atasoy', 'residence', 'Istanbul'], ['Nurhan_Atasoy', 'residence', 'Turkey'], ['Nurhan_Atasoy', 'nationality', 'Turkish_people']], '1': [['Turkey', 'capital', 'Ankara']], '2': [['Turkish_people', 'religion', 'Irreligion']]}
# 1 ['Imagine_(John_Lennon_song) followedBy Happy_Xmas_(War_Is_Over)', 'Mermaid_(Train_song) musicalBand Train_(band)', 'Mermaid_(Train_song) followedBy Imagine_(John_Lennon_song)', 'Imagine_(John_Lennon_song) musicalArtist John_Lennon', '']
# subject_dict: {'Imagine_(John_Lennon_song)': [['Imagine_(John_Lennon_song)', 'followedBy', 'Happy_Xmas_(War_Is_Over)'], ['Imagine_(John_Lennon_song)', 'musicalArtist', 'John_Lennon']], 'Mermaid_(Train_song)': [['Mermaid_(Train_song)', 'musicalBand', 'Train_(band)'], ['Mermaid_(Train_song)', 'followedBy', 'Imagine_(John_Lennon_song)']]}
# object_dict: {'Imagine_(John_Lennon_song)': [['Mermaid_(Train_song)', 'followedBy', 'Imagine_(John_Lennon_song)'], ['Mermaid_(Train_song)', 'followedBy', 'Imagine_(John_Lennon_song)']]}
# merged_dict: {'0': [['Imagine_(John_Lennon_song)', 'followedBy', 'Happy_Xmas_(War_Is_Over)'], ['Imagine_(John_Lennon_song)', 'musicalArtist', 'John_Lennon']], '1': [['Mermaid_(Train_song)', 'musicalBand', 'Train_(band)'], ['Mermaid_(Train_song)', 'followedBy', 'Imagine_(John_Lennon_song)']]}
# 1 ['Liselotte_Grschebina birthPlace Karlsruhe', 'Liselotte_Grschebina deathPlace Israel', 'Israel ethnicGroup Arab_citizens_of_Israel', '']
# subject_dict: {'Liselotte_Grschebina': [['Liselotte_Grschebina', 'birthPlace', 'Karlsruhe'], ['Liselotte_Grschebina', 'deathPlace', 'Israel']], 'Israel': [['Israel', 'ethnicGroup', 'Arab_citizens_of_Israel']]}
# object_dict: {'Israel': [['Liselotte_Grschebina', 'deathPlace', 'Israel']]}
# merged_dict: {'0': [['Liselotte_Grschebina', 'birthPlace', 'Karlsruhe'], ['Liselotte_Grschebina', 'deathPlace', 'Israel']], '1': [['Israel', 'ethnicGroup', 'Arab_citizens_of_Israel']]}
# 1 ['Liselotte_Grschebina nationality Israel', 'Liselotte_Grschebina birthPlace German_Empire', 'Israel language Modern_Hebrew', '']
# subject_dict: {'Liselotte_Grschebina': [['Liselotte_Grschebina', 'nationality', 'Israel'], ['Liselotte_Grschebina', 'birthPlace', 'German_Empire']], 'Israel': [['Israel', 'language', 'Modern_Hebrew']]}
# object_dict: {'Israel': [['Liselotte_Grschebina', 'nationality', 'Israel']]}
# merged_dict: {'0': [['Liselotte_Grschebina', 'nationality', 'Israel'], ['Liselotte_Grschebina', 'birthPlace', 'German_Empire']], '1': [['Israel', 'language', 'Modern_Hebrew']]}
# 1 ['Mexico currency Mexican_peso', 'Mexico demonym Mexicans', 'Bionico course Dessert', 'Bionico region Guadalajara', 'Mexico leader Silvano_Aureoles_Conejo', 'Bionico ingredient Granola', 'Bionico country Mexico', '']
# subject_dict: {'Mexico': [['Mexico', 'currency', 'Mexican_peso'], ['Mexico', 'demonym', 'Mexicans'], ['Mexico', 'leader', 'Silvano_Aureoles_Conejo']], 'Bionico': [['Bionico', 'course', 'Dessert'], ['Bionico', 'region', 'Guadalajara'], ['Bionico', 'ingredient', 'Granola'], ['Bionico', 'country', 'Mexico']]}
# object_dict: {'Mexico': [['Bionico', 'country', 'Mexico'], ['Bionico', 'country', 'Mexico'], ['Bionico', 'country', 'Mexico']]}
# merged_dict: {'0': [['Mexico', 'currency', 'Mexican_peso'], ['Mexico', 'demonym', 'Mexicans'], ['Mexico', 'leader', 'Silvano_Aureoles_Conejo']], '1': [['Bionico', 'course', 'Dessert'], ['Bionico', 'region', 'Guadalajara'], ['Bionico', 'ingredient', 'Granola'], ['Bionico', 'country', 'Mexico']]}
# 1 ['Darinka_Dentcheva citizenship United_States', 'United_States motto "In God we trust"', 'Darinka_Dentcheva influencedBy Andrzej_Piotr_Ruszczyński', 'Andrzej_Piotr_Ruszczyński professionalField Mathematical_optimization', '']
# subject_dict: {'Darinka_Dentcheva': [['Darinka_Dentcheva', 'citizenship', 'United_States'], ['Darinka_Dentcheva', 'influencedBy', 'Andrzej_Piotr_Ruszczyński']], 'United_States': [['United_States', 'motto', '"In', 'God', 'we', 'trust"']], 'Andrzej_Piotr_Ruszczyński': [['Andrzej_Piotr_Ruszczyński', 'professionalField', 'Mathematical_optimization']]}
# object_dict: {'United_States': [['Darinka_Dentcheva', 'citizenship', 'United_States']], 'Andrzej_Piotr_Ruszczyński': [['Darinka_Dentcheva', 'influencedBy', 'Andrzej_Piotr_Ruszczyński']]}
# merged_dict: {'0': [['Darinka_Dentcheva', 'citizenship', 'United_States'], ['Darinka_Dentcheva', 'influencedBy', 'Andrzej_Piotr_Ruszczyński']], '1': [['United_States', 'motto', '"In', 'God', 'we', 'trust"']], '2': [['Andrzej_Piotr_Ruszczyński', 'professionalField', 'Mathematical_optimization']]}
# 1 ['Anatole_de_Grunwald birthPlace Saint_Petersburg', 'English_Without_Tears writer Anatole_de_Grunwald', 'English_Without_Tears writer Terence_Rattigan', '']
# subject_dict: {'Anatole_de_Grunwald': [['Anatole_de_Grunwald', 'birthPlace', 'Saint_Petersburg']], 'English_Without_Tears': [['English_Without_Tears', 'writer', 'Anatole_de_Grunwald'], ['English_Without_Tears', 'writer', 'Terence_Rattigan']]}
# object_dict: {'Anatole_de_Grunwald': [['English_Without_Tears', 'writer', 'Anatole_de_Grunwald']]}
# merged_dict: {'0': [['Anatole_de_Grunwald', 'birthPlace', 'Saint_Petersburg']], '1': [['English_Without_Tears', 'writer', 'Anatole_de_Grunwald'], ['English_Without_Tears', 'writer', 'Terence_Rattigan']]}
# 1 ['FC_Terek_Grozny ground Grozny', 'Aleksandr_Prudnikov currentclub FC_Amkar_Perm', 'Aleksandr_Prudnikov club FC_Terek_Grozny', 'Aleksandr_Prudnikov birthDate 1989-02-24', 'Aleksandr_Prudnikov youthclub FC_Spartak_Moscow', '']
# subject_dict: {'FC_Terek_Grozny': [['FC_Terek_Grozny', 'ground', 'Grozny']], 'Aleksandr_Prudnikov': [['Aleksandr_Prudnikov', 'currentclub', 'FC_Amkar_Perm'], ['Aleksandr_Prudnikov', 'club', 'FC_Terek_Grozny'], ['Aleksandr_Prudnikov', 'birthDate', '1989-02-24'], ['Aleksandr_Prudnikov', 'youthclub', 'FC_Spartak_Moscow']]}
# object_dict: {'FC_Terek_Grozny': [['Aleksandr_Prudnikov', 'club', 'FC_Terek_Grozny']]}
# merged_dict: {'0': [['FC_Terek_Grozny', 'ground', 'Grozny']], '1': [['Aleksandr_Prudnikov', 'currentclub', 'FC_Amkar_Perm'], ['Aleksandr_Prudnikov', 'club', 'FC_Terek_Grozny'], ['Aleksandr_Prudnikov', 'birthDate', '1989-02-24'], ['Aleksandr_Prudnikov', 'youthclub', 'FC_Spartak_Moscow']]}
# 1 ['Ciudad_Ayala country Mexico', 'Mexico populationDensity 61.0', 'Ciudad_Ayala timeZone Pacific_Daylight_Time', 'Ciudad_Ayala timeZone Pacific_Standard_Time_Zone', '']
# subject_dict: {'Ciudad_Ayala': [['Ciudad_Ayala', 'country', 'Mexico'], ['Ciudad_Ayala', 'timeZone', 'Pacific_Daylight_Time'], ['Ciudad_Ayala', 'timeZone', 'Pacific_Standard_Time_Zone']], 'Mexico': [['Mexico', 'populationDensity', '61.0']]}
# object_dict: {'Mexico': [['Ciudad_Ayala', 'country', 'Mexico']]}
# merged_dict: {'0': [['Ciudad_Ayala', 'country', 'Mexico'], ['Ciudad_Ayala', 'timeZone', 'Pacific_Daylight_Time'], ['Ciudad_Ayala', 'timeZone', 'Pacific_Standard_Time_Zone']], '1': [['Mexico', 'populationDensity', '61.0']]}
# 1 ['Liselotte_Grschebina deathPlace Israel', 'Israel populationDensity 387.63', 'Liselotte_Grschebina nationality Israel', '']
# subject_dict: {'Liselotte_Grschebina': [['Liselotte_Grschebina', 'deathPlace', 'Israel'], ['Liselotte_Grschebina', 'nationality', 'Israel']], 'Israel': [['Israel', 'populationDensity', '387.63']]}
# object_dict: {'Israel': [['Liselotte_Grschebina', 'deathPlace', 'Israel'], ['Liselotte_Grschebina', 'nationality', 'Israel']]}
# merged_dict: {'0': [['Liselotte_Grschebina', 'deathPlace', 'Israel'], ['Liselotte_Grschebina', 'nationality', 'Israel']], '1': [['Israel', 'populationDensity', '387.63']]}
# 1 ['Nie_Haisheng birthPlace Zaoyang', 'Nie_Haisheng mission Shenzhou_6', 'Zaoyang isPartOf Hubei', '']
# subject_dict: {'Nie_Haisheng': [['Nie_Haisheng', 'birthPlace', 'Zaoyang'], ['Nie_Haisheng', 'mission', 'Shenzhou_6']], 'Zaoyang': [['Zaoyang', 'isPartOf', 'Hubei']]}
# object_dict: {'Zaoyang': [['Nie_Haisheng', 'birthPlace', 'Zaoyang']]}
# merged_dict: {'0': [['Nie_Haisheng', 'birthPlace', 'Zaoyang'], ['Nie_Haisheng', 'mission', 'Shenzhou_6']], '1': [['Zaoyang', 'isPartOf', 'Hubei']]}
# 1 ['Mexico currency Mexican_peso', 'Mexico demonym Mexicans', 'Bionico course Dessert', 'Bionico region Guadalajara', 'Dessert dishVariation Cookie', 'Bionico country Mexico', '']
# subject_dict: {'Mexico': [['Mexico', 'currency', 'Mexican_peso'], ['Mexico', 'demonym', 'Mexicans']], 'Bionico': [['Bionico', 'course', 'Dessert'], ['Bionico', 'region', 'Guadalajara'], ['Bionico', 'country', 'Mexico']], 'Dessert': [['Dessert', 'dishVariation', 'Cookie']]}
# object_dict: {'Mexico': [['Bionico', 'country', 'Mexico'], ['Bionico', 'country', 'Mexico']], 'Dessert': [['Bionico', 'course', 'Dessert']]}
# merged_dict: {'0': [['Mexico', 'currency', 'Mexican_peso'], ['Mexico', 'demonym', 'Mexicans']], '1': [['Bionico', 'course', 'Dessert'], ['Bionico', 'region', 'Guadalajara'], ['Bionico', 'country', 'Mexico']], '2': [['Dessert', 'dishVariation', 'Cookie']]}
#    id                                            triples  \
# 0   0  Adams_County,_Pennsylvania hasToItsWest Frankl...
# 1   0  11th_Mississippi_Infantry_Monument established...
# 2   1                       BBC city Broadcasting_House
# 3   1  Bananaman starring Bill_Oddie Bananaman broadc...
# 4   2                  Karlsruhe postalCode 76131–76229
#
#                                            data_unit  \
# 0  Adams_County,_Pennsylvania hasToItsWest Frankl...
# 1  Adams_County,_Pennsylvania hasToItsWest Frankl...
# 2  BBC city Broadcasting_House | Bananaman starri...
# 3  BBC city Broadcasting_House | Bananaman starri...
# 4                Karlsruhe postalCode 76131–76229 |
#
#                                               actual                shape  \
# 0  A monument to the 11th Mississippi Infantry, w...  (X (X) (X) (X (X)))
# 1  A monument to the 11th Mississippi Infantry, w...  (X (X) (X) (X (X)))
# 2  Bill Oddie stars in a BBC programme called Ban...      (X (X) (X (X)))
# 3  Bill Oddie stars in a BBC programme called Ban...      (X (X) (X (X)))
# 4     The postal codes of Karlsruhe are 76131–76229.              (X (X))
#
#   shape_type  local_size  size
# 0      mixed           1     4
# 1      mixed           3     4
# 2      mixed           1     3
# 3      mixed           2     3
# 4        NaN           1     1

# %%
def split_dict(dict_to_split):
    new_dict = {}
    for key, value in dict_to_split.items():
        num_chunks = (len(value) + 2) // 3  # Calcoliamo il numero di chunk necessari
        for i in range(num_chunks):
            new_key = f"{key}_{i}" if i > 0 else key  # Creiamo una nuova chiave con indice se necessario
            start = i * 3
            end = min((i + 1) * 3, len(value))
            new_dict[new_key] = value[start:end]  # Aggiungiamo i valori corrispondenti
    return new_dict

dict_to_split = {'0': [['William_Anders', 'mission', 'Apollo_8'], ['Apollo_8', 'crew1Up', 'Frank_Borman'], ['Apollo_8', 'crew2Up', 'Buzz_Aldrin'], ['Apollo_8', 'operator', 'NASA']]}

split_dict_result = split_dict(dict_to_split)

for key, value in split_dict_result.items():
    print(f"{key}: {value}")
# Out:
# 0: [['William_Anders', 'mission', 'Apollo_8'], ['Apollo_8', 'crew1Up', 'Frank_Borman'], ['Apollo_8', 'crew2Up', 'Buzz_Aldrin']]
# 0_1: [['Apollo_8', 'operator', 'NASA']]
