# %%
#utils
import pandas as pd
import os
import numpy as np
from nltk.tokenize import word_tokenize

# %%
dataset_names = [
    'D2T-1-CFA_WebNLG_CounterFactual',
    'D2T-1-FA_WebNLG_Factual',
    'D2T-1-FI_WebNLG_Fictional',
    'D2T-2-CFA_Wikidata_CounterFactual',
    'D2T-2-FA_Wikidata_Factual',
    'D2T-2-FI_Wikidata_Fictional',
    'dev',
    'train',
]

# %% [markdown]
# ## FUNCTIONS

# %%
def merge_dicts(dict1, dict2):
    #print(f'START MERGE_DICTS')
    merged_dict = {}
    for key, value in dict1.items():
        merged_dict[key] = dict1[key]

        if key in dict2:
            for triple in value:
                flag = True
                for key, value in merged_dict.items():
                    if triple in value:
                        flag = False
                        break

                if flag:
                    merged_dict[key].insert(0, triple)
        else:
            merged_dict[key] = value

    keys = list(merged_dict.keys())
    values = list(merged_dict.values())
    keys = [str(i) for i in range(len(keys))]
    merged_dict = dict(zip(keys, values))
    print(f'merged_dict: {merged_dict}')

    #print(f'END MERGE_DICTS')
    return merged_dict

def split_mixed(triples):
    subject_dict = {}
    object_dict = {}
    #print(f'START SPLIT_MIXED')
    for triple in triples:
        triple = triple.split(' ')

        if len(triple) > 1:
            # sibling
            subject = triple[0]

            if subject in subject_dict:
                subject_dict[subject].append(triple)
            else:
                subject_dict[subject] = [triple]

            # chain
            object = triple[0]

            for triple in triples:
                triple = triple.split(' ')

                if len(triple) > 1:
                    if triple[2] == object:
                        if object in object_dict:
                            object_dict[object].append(triple)
                        else:
                            object_dict[object] = [triple]

    print(f'subject_dict: {subject_dict}')
    print(f'object_dict: {object_dict}')

    #print(f'subject_dict: {subject_dict}')
    #print(f'object_dict: {object_dict}')

    merged_dict = merge_dicts(subject_dict, object_dict)

    #print(f'END SPLIT_MIXED')
    return merged_dict

# %%
#splitta il dizionario in gruppi di 3 nel caso ci fossero chiavi con piu di 3 valori
def split_dict(dict_to_split):
    new_dict = {}
    for key, value in dict_to_split.items():
        num_chunks = (len(value) + 2) // 3  # Calcoliamo il numero di chunk necessari
        for i in range(num_chunks):
            new_key = f"{key}_{i}" if i > 0 else key  # Creiamo una nuova chiave con indice se necessario
            start = i * 3
            end = min((i + 1) * 3, len(value))
            new_dict[new_key] = value[start:end]  # Aggiungiamo i valori corrispondenti
    return new_dict

# %%
def create_dict_with_max_values(array, max_values_per_key):
    array = [triple for triple in array if triple.strip()]  # Rimuovi le stringhe vuote
    result_dict = {}
    current_key_index = 0
    current_key_values = []
    for triple in array:
        current_key_values.append(triple.split(' '))
        if len(current_key_values) == max_values_per_key:
            result_dict[current_key_index] = current_key_values
            current_key_index += 1
            current_key_values = []
    # Aggiungi eventuali valori rimanenti
    if current_key_values:
        result_dict[current_key_index] = current_key_values
    return result_dict

# %% [markdown]
# ## MAIN

# %%
for dataset_name in dataset_names:
    print(f'Processing {dataset_name}')
    #dataset = pd.read_csv(f'../GEM/data_formatted/{dataset_name}.csv')
    full_dataset = pd.read_csv(f'pre-processed-data\\{dataset_name}.csv')
    # get only 1000 random rows from dataset with random seed = 42
    perc_d = 1000 / len(full_dataset)
    dataset = full_dataset.sample(frac=perc_d, random_state=42)

    # refresh index
    dataset = dataset.reset_index(drop=True)

    triples_dict = {}
    j = 0
    for i in range(len(dataset)):
        triples = dataset['triple'][i].split(' | ')

        if (dataset['shape_type'][i] == 'mixed' or dataset['shape_type'][i] == 'NA' or dataset['shape_type'][i] == 'unknown') and dataset['size'][i] > 2:
            print('1', triples)
            dictionary = split_mixed(triples)
            dictionary = split_dict(dictionary)
        else:
            dictionary = create_dict_with_max_values(triples, 3)

        
            
        for key, value in dictionary.items():
            value_text = ''
            for triple in value:
                value_text += ' '.join(triple) + ' '

            triples_dict[j] = {
                'id': i,
                'triples': value_text,
                'data_unit' : dataset['triple'][i],
                'actual' : dataset['sentence'][i],
                'shape' : dataset['shape'][i],
                'shape_type' : dataset['shape_type'][i],
                'local_size' : len(value),
                'size' : dataset['size'][i],
            }
            j += 1

    triples_df = pd.DataFrame.from_dict(triples_dict, "index")
    triples_df.to_csv(f'splitted-data\\{dataset_name}.csv', index=False)

triples_df.head()
# Out:
# Processing D2T-1-CFA_WebNLG_CounterFactual
# 1 ['Larry_Sanger birthPlace Białystok Białystok timeZone Moscow_Time Larry_Sanger weight 20378.5 ']
# subject_dict: {'Larry_Sanger': [['Larry_Sanger', 'birthPlace', 'Białystok', 'Białystok', 'timeZone', 'Moscow_Time', 'Larry_Sanger', 'weight', '20378.5', '']]}
# object_dict: {}
# merged_dict: {'0': [['Larry_Sanger', 'birthPlace', 'Białystok', 'Białystok', 'timeZone', 'Moscow_Time', 'Larry_Sanger', 'weight', '20378.5', '']]}
# 1 ['Moritzbastei address 200_Public_Square Vlerick_Business_School country "United_States" Moritzbastei currentTenants Vlerick_Business_School Moritzbastei location New_Hampshire ']
# subject_dict: {'Moritzbastei': [['Moritzbastei', 'address', '200_Public_Square', 'Vlerick_Business_School', 'country', '"United_States"', 'Moritzbastei', 'currentTenants', 'Vlerick_Business_School', 'Moritzbastei', 'location', 'New_Hampshire', '']]}
# object_dict: {}
# merged_dict: {'0': [['Moritzbastei', 'address', '200_Public_Square', 'Vlerick_Business_School', 'country', '"United_States"', 'Moritzbastei', 'currentTenants', 'Vlerick_Business_School', 'Moritzbastei', 'location', 'New_Hampshire', '']]}
# 1 ['Trinidad_and_Tobago_Civil_Aviation_Authority city Cabreros_del_Río Cabreros_del_Río country United_States Bahrain_International_Airport location Almenara_de_Adaja Bahrain_International_Airport operatingOrganisation Trinidad_and_Tobago_Civil_Aviation_Authority Bahrain_International_Airport runwayLength 2900 Bahrain_International_Airport runwayName "09R/27L" ']
# subject_dict: {'Trinidad_and_Tobago_Civil_Aviation_Authority': [['Trinidad_and_Tobago_Civil_Aviation_Authority', 'city', 'Cabreros_del_Río', 'Cabreros_del_Río', 'country', 'United_States', 'Bahrain_International_Airport', 'location', 'Almenara_de_Adaja', 'Bahrain_International_Airport', 'operatingOrganisation', 'Trinidad_and_Tobago_Civil_Aviation_Authority', 'Bahrain_International_Airport', 'runwayLength', '2900', 'Bahrain_International_Airport', 'runwayName', '"09R/27L"', '']]}
# object_dict: {}
# merged_dict: {'0': [['Trinidad_and_Tobago_Civil_Aviation_Authority', 'city', 'Cabreros_del_Río', 'Cabreros_del_Río', 'country', 'United_States', 'Bahrain_International_Airport', 'location', 'Almenara_de_Adaja', 'Bahrain_International_Airport', 'operatingOrganisation', 'Trinidad_and_Tobago_Civil_Aviation_Authority', 'Bahrain_International_Airport', 'runwayLength', '2900', 'Bahrain_International_Airport', 'runwayName', '"09R/27L"', '']]}
# 1 ['Emil_Rilke background "Ruth_Ribicoff" Deathdream musicComposer Emil_Rilke Deathdream producer Sachin_Tendulkar Deathdream releaseDate "1923-11-18" ']
# subject_dict: {'Emil_Rilke': [['Emil_Rilke', 'background', '"Ruth_Ribicoff"', 'Deathdream', 'musicComposer', 'Emil_Rilke', 'Deathdream', 'producer', 'Sachin_Tendulkar', 'Deathdream', 'releaseDate', '"1923-11-18"', '']]}
# object_dict: {}
# merged_dict: {'0': [['Emil_Rilke', 'background', '"Ruth_Ribicoff"', 'Deathdream', 'musicComposer', 'Emil_Rilke', 'Deathdream', 'producer', 'Sachin_Tendulkar', 'Deathdream', 'releaseDate', '"1923-11-18"', '']]}
# 1 ['The_Violinist category Contributing_property The_Violinist country Israel Costilla_County hasToItsSoutheast Carroll_County_Maryland The_Violinist location Costilla_County ']
# subject_dict: {'The_Violinist': [['The_Violinist', 'category', 'Contributing_property', 'The_Violinist', 'country', 'Israel', 'Costilla_County', 'hasToItsSoutheast', 'Carroll_County_Maryland', 'The_Violinist', 'location', 'Costilla_County', '']]}
# object_dict: {}
# merged_dict: {'0': [['The_Violinist', 'category', 'Contributing_property', 'The_Violinist', 'country', 'Israel', 'Costilla_County', 'hasToItsSoutheast', 'Carroll_County_Maryland', 'The_Violinist', 'location', 'Costilla_County', '']]}
# 1 ['Fort_William_College campus The_Progressive_Motion_Picture_Company Fort_William_College city Behringwerke Fort_William_College director Marie_Curie Fort_William_College established 2000 Polish_Social_and_Cultural_Association location Shanghai Fort_William_College wasGivenTheTechnicalCampusStatusBy Polish_Social_and_Cultural_Association ']
# subject_dict: {'Fort_William_College': [['Fort_William_College', 'campus', 'The_Progressive_Motion_Picture_Company', 'Fort_William_College', 'city', 'Behringwerke', 'Fort_William_College', 'director', 'Marie_Curie', 'Fort_William_College', 'established', '2000', 'Polish_Social_and_Cultural_Association', 'location', 'Shanghai', 'Fort_William_College', 'wasGivenTheTechnicalCampusStatusBy', 'Polish_Social_and_Cultural_Association', '']]}
# object_dict: {}
# merged_dict: {'0': [['Fort_William_College', 'campus', 'The_Progressive_Motion_Picture_Company', 'Fort_William_College', 'city', 'Behringwerke', 'Fort_William_College', 'director', 'Marie_Curie', 'Fort_William_College', 'established', '2000', 'Polish_Social_and_Cultural_Association', 'location', 'Shanghai', 'Fort_William_College', 'wasGivenTheTechnicalCampusStatusBy', 'Polish_Social_and_Cultural_Association', '']]}
# 1 ['Carlo_Azeglio_Ciampi birthPlace Karlsruhe Karlsruhe country France United_States language Caluyanon Carlo_Azeglio_Ciampi nationality United_States Carlo_Azeglio_Ciampi training School_of_Applied_Arts_in_Stuttgart ']
# subject_dict: {'Carlo_Azeglio_Ciampi': [['Carlo_Azeglio_Ciampi', 'birthPlace', 'Karlsruhe', 'Karlsruhe', 'country', 'France', 'United_States', 'language', 'Caluyanon', 'Carlo_Azeglio_Ciampi', 'nationality', 'United_States', 'Carlo_Azeglio_Ciampi', 'training', 'School_of_Applied_Arts_in_Stuttgart', '']]}
# object_dict: {}
# merged_dict: {'0': [['Carlo_Azeglio_Ciampi', 'birthPlace', 'Karlsruhe', 'Karlsruhe', 'country', 'France', 'United_States', 'language', 'Caluyanon', 'Carlo_Azeglio_Ciampi', 'nationality', 'United_States', 'Carlo_Azeglio_Ciampi', 'training', 'School_of_Applied_Arts_in_Stuttgart', '']]}
# 1 ['Šiauliai_State_College campus Steve_Bright Šiauliai_State_College city Industries_et_Agro-Ressources Šiauliai_State_College director Sarah_Teale Industries_et_Agro-Ressources founder Albert_Einstein Polish_Underground_State location Shanghai Šiauliai_State_College numberOfPostgraduateStudents 1542 Šiauliai_State_College wasGivenTheTechnicalCampusStatusBy Polish_Underground_State ']
# subject_dict: {'Šiauliai_State_College': [['Šiauliai_State_College', 'campus', 'Steve_Bright', 'Šiauliai_State_College', 'city', 'Industries_et_Agro-Ressources', 'Šiauliai_State_College', 'director', 'Sarah_Teale', 'Industries_et_Agro-Ressources', 'founder', 'Albert_Einstein', 'Polish_Underground_State', 'location', 'Shanghai', 'Šiauliai_State_College', 'numberOfPostgraduateStudents', '1542', 'Šiauliai_State_College', 'wasGivenTheTechnicalCampusStatusBy', 'Polish_Underground_State', '']]}
# object_dict: {}
# merged_dict: {'0': [['Šiauliai_State_College', 'campus', 'Steve_Bright', 'Šiauliai_State_College', 'city', 'Industries_et_Agro-Ressources', 'Šiauliai_State_College', 'director', 'Sarah_Teale', 'Industries_et_Agro-Ressources', 'founder', 'Albert_Einstein', 'Polish_Underground_State', 'location', 'Shanghai', 'Šiauliai_State_College', 'numberOfPostgraduateStudents', '1542', 'Šiauliai_State_College', 'wasGivenTheTechnicalCampusStatusBy', 'Polish_Underground_State', '']]}
# 1 ['Skelmersdale_United_F.C. chairmanTitle peritus Equatoguinean_Premier_League champions Cagliari_Calcio Equatoguinean_Premier_League country Israel Skelmersdale_United_F.C. ground Estadio_Jorge_Luis_Hirschi Skelmersdale_United_F.C. league Equatoguinean_Premier_League Estadio_Jorge_Luis_Hirschi location Jequitinhonha Skelmersdale_United_F.C. numberOfMembers 1439.0 ']
# subject_dict: {'Skelmersdale_United_F.C.': [['Skelmersdale_United_F.C.', 'chairmanTitle', 'peritus', 'Equatoguinean_Premier_League', 'champions', 'Cagliari_Calcio', 'Equatoguinean_Premier_League', 'country', 'Israel', 'Skelmersdale_United_F.C.', 'ground', 'Estadio_Jorge_Luis_Hirschi', 'Skelmersdale_United_F.C.', 'league', 'Equatoguinean_Premier_League', 'Estadio_Jorge_Luis_Hirschi', 'location', 'Jequitinhonha', 'Skelmersdale_United_F.C.', 'numberOfMembers', '1439.0', '']]}
# object_dict: {}
# merged_dict: {'0': [['Skelmersdale_United_F.C.', 'chairmanTitle', 'peritus', 'Equatoguinean_Premier_League', 'champions', 'Cagliari_Calcio', 'Equatoguinean_Premier_League', 'country', 'Israel', 'Skelmersdale_United_F.C.', 'ground', 'Estadio_Jorge_Luis_Hirschi', 'Skelmersdale_United_F.C.', 'league', 'Equatoguinean_Premier_League', 'Estadio_Jorge_Luis_Hirschi', 'location', 'Jequitinhonha', 'Skelmersdale_United_F.C.', 'numberOfMembers', '1439.0', '']]}
# 1 ['Jennette_McCurdy almaMater Kyung_Hee_University Jennette_McCurdy deathPlace Leningrad_USSR Leningrad_USSR foundingDate 1942-01-01 ']
# subject_dict: {'Jennette_McCurdy': [['Jennette_McCurdy', 'almaMater', 'Kyung_Hee_University', 'Jennette_McCurdy', 'deathPlace', 'Leningrad_USSR', 'Leningrad_USSR', 'foundingDate', '1942-01-01', '']]}
# object_dict: {}
# merged_dict: {'0': [['Jennette_McCurdy', 'almaMater', 'Kyung_Hee_University', 'Jennette_McCurdy', 'deathPlace', 'Leningrad_USSR', 'Leningrad_USSR', 'foundingDate', '1942-01-01', '']]}
# 1 ["Barnsley_College campus Stacy_Katzman Barnsley_College city Clúster_de_la_Indústria_d'Automoció_de_Catalunya Barnsley_College director NZ289147 Polish_Social_and_Cultural_Association location Dhaka Barnsley_College wasGivenTheTechnicalCampusStatusBy Polish_Social_and_Cultural_Association "]
# subject_dict: {'Barnsley_College': [['Barnsley_College', 'campus', 'Stacy_Katzman', 'Barnsley_College', 'city', "Clúster_de_la_Indústria_d'Automoció_de_Catalunya", 'Barnsley_College', 'director', 'NZ289147', 'Polish_Social_and_Cultural_Association', 'location', 'Dhaka', 'Barnsley_College', 'wasGivenTheTechnicalCampusStatusBy', 'Polish_Social_and_Cultural_Association', '']]}
# object_dict: {}
# merged_dict: {'0': [['Barnsley_College', 'campus', 'Stacy_Katzman', 'Barnsley_College', 'city', "Clúster_de_la_Indústria_d'Automoció_de_Catalunya", 'Barnsley_College', 'director', 'NZ289147', 'Polish_Social_and_Cultural_Association', 'location', 'Dhaka', 'Barnsley_College', 'wasGivenTheTechnicalCampusStatusBy', 'Polish_Social_and_Cultural_Association', '']]}
# 1 ['Monument_of_Alexander_III category Contributing_property Monument_of_Alexander_III country France Monument_of_Alexander_III established 2000 Cheyenne_County hasToItsNorth Cumberland_County_Pennsylvania Monument_of_Alexander_III location Cheyenne_County ']
# subject_dict: {'Monument_of_Alexander_III': [['Monument_of_Alexander_III', 'category', 'Contributing_property', 'Monument_of_Alexander_III', 'country', 'France', 'Monument_of_Alexander_III', 'established', '2000', 'Cheyenne_County', 'hasToItsNorth', 'Cumberland_County_Pennsylvania', 'Monument_of_Alexander_III', 'location', 'Cheyenne_County', '']]}
# object_dict: {}
# merged_dict: {'0': [['Monument_of_Alexander_III', 'category', 'Contributing_property', 'Monument_of_Alexander_III', 'country', 'France', 'Monument_of_Alexander_III', 'established', '2000', 'Cheyenne_County', 'hasToItsNorth', 'Cumberland_County_Pennsylvania', 'Monument_of_Alexander_III', 'location', 'Cheyenne_County', '']]}
# 1 ['Oman_Professional_League champions Halesowen_Town_F.C. Oman_Professional_League country Israel Tetley_Walker_F.C. fullName Bridon_Ropes_F.C. Tetley_Walker_F.C. ground Stade_Vuillermet Tetley_Walker_F.C. league Oman_Professional_League Stade_Vuillermet location Ilhéus Tetley_Walker_F.C. season 1765 ']
# subject_dict: {'Oman_Professional_League': [['Oman_Professional_League', 'champions', 'Halesowen_Town_F.C.', 'Oman_Professional_League', 'country', 'Israel', 'Tetley_Walker_F.C.', 'fullName', 'Bridon_Ropes_F.C.', 'Tetley_Walker_F.C.', 'ground', 'Stade_Vuillermet', 'Tetley_Walker_F.C.', 'league', 'Oman_Professional_League', 'Stade_Vuillermet', 'location', 'Ilhéus', 'Tetley_Walker_F.C.', 'season', '1765', '']]}
# object_dict: {}
# merged_dict: {'0': [['Oman_Professional_League', 'champions', 'Halesowen_Town_F.C.', 'Oman_Professional_League', 'country', 'Israel', 'Tetley_Walker_F.C.', 'fullName', 'Bridon_Ropes_F.C.', 'Tetley_Walker_F.C.', 'ground', 'Stade_Vuillermet', 'Tetley_Walker_F.C.', 'league', 'Oman_Professional_League', 'Stade_Vuillermet', 'location', 'Ilhéus', 'Tetley_Walker_F.C.', 'season', '1765', '']]}
# 1 ['Iraqi_Premier_League country "United_States" Lincoln_United_F.C. league Iraqi_Premier_League Lincoln_United_F.C. nickname "B.M._Reddy" ']
# subject_dict: {'Iraqi_Premier_League': [['Iraqi_Premier_League', 'country', '"United_States"', 'Lincoln_United_F.C.', 'league', 'Iraqi_Premier_League', 'Lincoln_United_F.C.', 'nickname', '"B.M._Reddy"', '']]}
# object_dict: {}
# merged_dict: {'0': [['Iraqi_Premier_League', 'country', '"United_States"', 'Lincoln_United_F.C.', 'league', 'Iraqi_Premier_League', 'Lincoln_United_F.C.', 'nickname', '"B.M._Reddy"', '']]}
# 1 ['England areaTotal 1604.0 England leader Elisa_Uga Jacques_Brel nationality Duchy_of_Guelders Jacques_Brel residence England ']
# subject_dict: {'England': [['England', 'areaTotal', '1604.0', 'England', 'leader', 'Elisa_Uga', 'Jacques_Brel', 'nationality', 'Duchy_of_Guelders', 'Jacques_Brel', 'residence', 'England', '']]}
# object_dict: {}
# merged_dict: {'0': [['England', 'areaTotal', '1604.0', 'England', 'leader', 'Elisa_Uga', 'Jacques_Brel', 'nationality', 'Duchy_of_Guelders', 'Jacques_Brel', 'residence', 'England', '']]}
# 1 ['Mexico areaTotal 83.0 The_Video_Collection:_1997–2003 recordedIn Bibb_County The_Video_Collection:_1997–2003 recordedIn Mexico Bibb_County utcOffset "\'\'Alvinegro" ']
# subject_dict: {'Mexico': [['Mexico', 'areaTotal', '83.0', 'The_Video_Collection:_1997–2003', 'recordedIn', 'Bibb_County', 'The_Video_Collection:_1997–2003', 'recordedIn', 'Mexico', 'Bibb_County', 'utcOffset', '"\'\'Alvinegro"', '']]}
# object_dict: {}
# merged_dict: {'0': [['Mexico', 'areaTotal', '83.0', 'The_Video_Collection:_1997–2003', 'recordedIn', 'Bibb_County', 'The_Video_Collection:_1997–2003', 'recordedIn', 'Mexico', 'Bibb_County', 'utcOffset', '"\'\'Alvinegro"', '']]}
# 1 ['Castel_Film_Romania followedBy Jackson_5_Christmas_Album Mermaid_(Train_song) followedBy Castel_Film_Romania Mermaid_(Train_song) genre alternative_hip_hop Castel_Film_Romania genre ska ']
# subject_dict: {'Castel_Film_Romania': [['Castel_Film_Romania', 'followedBy', 'Jackson_5_Christmas_Album', 'Mermaid_(Train_song)', 'followedBy', 'Castel_Film_Romania', 'Mermaid_(Train_song)', 'genre', 'alternative_hip_hop', 'Castel_Film_Romania', 'genre', 'ska', '']]}
# object_dict: {}
# merged_dict: {'0': [['Castel_Film_Romania', 'followedBy', 'Jackson_5_Christmas_Album', 'Mermaid_(Train_song)', 'followedBy', 'Castel_Film_Romania', 'Mermaid_(Train_song)', 'genre', 'alternative_hip_hop', 'Castel_Film_Romania', 'genre', 'ska', '']]}
# 1 ['Barisal_Government_Women’s_College affiliation Medical_University_of_Łódź Barisal_Government_Women’s_College campus School_of_Applied_Arts_in_Stuttgart Automóvel_Club_de_Portugal location Seoul Barisal_Government_Women’s_College president John_F._Kennedy Barisal_Government_Women’s_College wasGivenTheTechnicalCampusStatusBy Automóvel_Club_de_Portugal ']
# subject_dict: {'Barisal_Government_Women’s_College': [['Barisal_Government_Women’s_College', 'affiliation', 'Medical_University_of_Łódź', 'Barisal_Government_Women’s_College', 'campus', 'School_of_Applied_Arts_in_Stuttgart', 'Automóvel_Club_de_Portugal', 'location', 'Seoul', 'Barisal_Government_Women’s_College', 'president', 'John_F._Kennedy', 'Barisal_Government_Women’s_College', 'wasGivenTheTechnicalCampusStatusBy', 'Automóvel_Club_de_Portugal', '']]}
# object_dict: {}
# merged_dict: {'0': [['Barisal_Government_Women’s_College', 'affiliation', 'Medical_University_of_Łódź', 'Barisal_Government_Women’s_College', 'campus', 'School_of_Applied_Arts_in_Stuttgart', 'Automóvel_Club_de_Portugal', 'location', 'Seoul', 'Barisal_Government_Women’s_College', 'president', 'John_F._Kennedy', 'Barisal_Government_Women’s_College', 'wasGivenTheTechnicalCampusStatusBy', 'Automóvel_Club_de_Portugal', '']]}
# 1 ['Mermaid_(Train_song) followedBy neue_deutsche_Filmgesellschaft neue_deutsche_Filmgesellschaft followedBy A_Momentary_Lapse_of_Reason Mermaid_(Train_song) precededBy "Dr._G._P._Prabhukumar" ']
# subject_dict: {'Mermaid_(Train_song)': [['Mermaid_(Train_song)', 'followedBy', 'neue_deutsche_Filmgesellschaft', 'neue_deutsche_Filmgesellschaft', 'followedBy', 'A_Momentary_Lapse_of_Reason', 'Mermaid_(Train_song)', 'precededBy', '"Dr._G._P._Prabhukumar"', '']]}
# object_dict: {}
# merged_dict: {'0': [['Mermaid_(Train_song)', 'followedBy', 'neue_deutsche_Filmgesellschaft', 'neue_deutsche_Filmgesellschaft', 'followedBy', 'A_Momentary_Lapse_of_Reason', 'Mermaid_(Train_song)', 'precededBy', '"Dr._G._P._Prabhukumar"', '']]}
# 1 ['Direction_des_Services_de_la_navigation_aérienne city Guadalaviar Dera_Ghazi_Khan_International_Airport elevationAboveTheSeaLevel 12 Dera_Ghazi_Khan_International_Airport operatingOrganisation Direction_des_Services_de_la_navigation_aérienne Dera_Ghazi_Khan_International_Airport runwayLength 27400 ']
# subject_dict: {'Direction_des_Services_de_la_navigation_aérienne': [['Direction_des_Services_de_la_navigation_aérienne', 'city', 'Guadalaviar', 'Dera_Ghazi_Khan_International_Airport', 'elevationAboveTheSeaLevel', '12', 'Dera_Ghazi_Khan_International_Airport', 'operatingOrganisation', 'Direction_des_Services_de_la_navigation_aérienne', 'Dera_Ghazi_Khan_International_Airport', 'runwayLength', '27400', '']]}
# object_dict: {}
# merged_dict: {'0': [['Direction_des_Services_de_la_navigation_aérienne', 'city', 'Guadalaviar', 'Dera_Ghazi_Khan_International_Airport', 'elevationAboveTheSeaLevel', '12', 'Dera_Ghazi_Khan_International_Airport', 'operatingOrganisation', 'Direction_des_Services_de_la_navigation_aérienne', 'Dera_Ghazi_Khan_International_Airport', 'runwayLength', '27400', '']]}
# 1 ['Marforio category Contributing_property Marforio country Philippines Marforio established 2000 Eagle_County hasToItsSoutheast Carroll_County_Maryland Eagle_County hasToItsWest Franklin_County_Pennsylvania Marforio location Eagle_County Marforio municipality Cressona ']
# subject_dict: {'Marforio': [['Marforio', 'category', 'Contributing_property', 'Marforio', 'country', 'Philippines', 'Marforio', 'established', '2000', 'Eagle_County', 'hasToItsSoutheast', 'Carroll_County_Maryland', 'Eagle_County', 'hasToItsWest', 'Franklin_County_Pennsylvania', 'Marforio', 'location', 'Eagle_County', 'Marforio', 'municipality', 'Cressona', '']]}
# object_dict: {}
# merged_dict: {'0': [['Marforio', 'category', 'Contributing_property', 'Marforio', 'country', 'Philippines', 'Marforio', 'established', '2000', 'Eagle_County', 'hasToItsSoutheast', 'Carroll_County_Maryland', 'Eagle_County', 'hasToItsWest', 'Franklin_County_Pennsylvania', 'Marforio', 'location', 'Eagle_County', 'Marforio', 'municipality', 'Cressona', '']]}
# 1 ['Skeyes city Castrojeriz Manchester_Airport elevationAboveTheSeaLevel 1604.0 Manchester_Airport location Tarifa Manchester_Airport operatingOrganisation Skeyes Manchester_Airport runwayName "09L/27R" ']
# subject_dict: {'Skeyes': [['Skeyes', 'city', 'Castrojeriz', 'Manchester_Airport', 'elevationAboveTheSeaLevel', '1604.0', 'Manchester_Airport', 'location', 'Tarifa', 'Manchester_Airport', 'operatingOrganisation', 'Skeyes', 'Manchester_Airport', 'runwayName', '"09L/27R"', '']]}
# object_dict: {}
# merged_dict: {'0': [['Skeyes', 'city', 'Castrojeriz', 'Manchester_Airport', 'elevationAboveTheSeaLevel', '1604.0', 'Manchester_Airport', 'location', 'Tarifa', 'Manchester_Airport', 'operatingOrganisation', 'Skeyes', 'Manchester_Airport', 'runwayName', '"09L/27R"', '']]}
# 1 ['Caparezza deathPlace Leningrad_USSR Leningrad_USSR foundingDate 2012-12-27 Leningrad_USSR leaderTitle United_States_Secretary_of_State ']
# subject_dict: {'Caparezza': [['Caparezza', 'deathPlace', 'Leningrad_USSR', 'Leningrad_USSR', 'foundingDate', '2012-12-27', 'Leningrad_USSR', 'leaderTitle', 'United_States_Secretary_of_State', '']]}
# object_dict: {}
# merged_dict: {'0': [['Caparezza', 'deathPlace', 'Leningrad_USSR', 'Leningrad_USSR', 'foundingDate', '2012-12-27', 'Leningrad_USSR', 'leaderTitle', 'United_States_Secretary_of_State', '']]}
# 1 ['Jalisco areaTotal 2900 Jalisco country United_States Fuerte_Esperanza isPartOf Jalisco Fuerte_Esperanza populationDensity 94.0 ']
# subject_dict: {'Jalisco': [['Jalisco', 'areaTotal', '2900', 'Jalisco', 'country', 'United_States', 'Fuerte_Esperanza', 'isPartOf', 'Jalisco', 'Fuerte_Esperanza', 'populationDensity', '94.0', '']]}
# object_dict: {}
# merged_dict: {'0': [['Jalisco', 'areaTotal', '2900', 'Jalisco', 'country', 'United_States', 'Fuerte_Esperanza', 'isPartOf', 'Jalisco', 'Fuerte_Esperanza', 'populationDensity', '94.0', '']]}
# 1 ['Paraguayan_Primera_División champions Atalanta_BC Parma_Calcio_1913 league Paraguayan_Primera_División Parma_Calcio_1913 numberOfMembers 16800 ']
# subject_dict: {'Paraguayan_Primera_División': [['Paraguayan_Primera_División', 'champions', 'Atalanta_BC', 'Parma_Calcio_1913', 'league', 'Paraguayan_Primera_División', 'Parma_Calcio_1913', 'numberOfMembers', '16800', '']]}
# object_dict: {}
# merged_dict: {'0': [['Paraguayan_Primera_División', 'champions', 'Atalanta_BC', 'Parma_Calcio_1913', 'league', 'Paraguayan_Primera_División', 'Parma_Calcio_1913', 'numberOfMembers', '16800', '']]}
# 1 ['FC_Baku ground La_Romareda Rita_König height 17068.8_(millimetres) Rita_König youthclub FC_Baku ']
# subject_dict: {'FC_Baku': [['FC_Baku', 'ground', 'La_Romareda', 'Rita_König', 'height', '17068.8_(millimetres)', 'Rita_König', 'youthclub', 'FC_Baku', '']]}
# object_dict: {}
# merged_dict: {'0': [['FC_Baku', 'ground', 'La_Romareda', 'Rita_König', 'height', '17068.8_(millimetres)', 'Rita_König', 'youthclub', 'FC_Baku', '']]}
# 1 ['Bionico country Israel Israel currency papal_lira Israel demonym Brusselians Bionico ingredient Granola Bionico region Morelos ']
# subject_dict: {'Bionico': [['Bionico', 'country', 'Israel', 'Israel', 'currency', 'papal_lira', 'Israel', 'demonym', 'Brusselians', 'Bionico', 'ingredient', 'Granola', 'Bionico', 'region', 'Morelos', '']]}
# object_dict: {}
# merged_dict: {'0': [['Bionico', 'country', 'Israel', 'Israel', 'currency', 'papal_lira', 'Israel', 'demonym', 'Brusselians', 'Bionico', 'ingredient', 'Granola', 'Bionico', 'region', 'Morelos', '']]}
# 1 ['Rosa_Roth broadcastedBy car2go car2go city Broadcasting_House_Dornbusch Rosa_Roth creator Stacy_Katzman Rosa_Roth lastAired 1946-12-17 Rosa_Roth starring Bruce_Matthews ']
# subject_dict: {'Rosa_Roth': [['Rosa_Roth', 'broadcastedBy', 'car2go', 'car2go', 'city', 'Broadcasting_House_Dornbusch', 'Rosa_Roth', 'creator', 'Stacy_Katzman', 'Rosa_Roth', 'lastAired', '1946-12-17', 'Rosa_Roth', 'starring', 'Bruce_Matthews', '']]}
# object_dict: {}
# merged_dict: {'0': [['Rosa_Roth', 'broadcastedBy', 'car2go', 'car2go', 'city', 'Broadcasting_House_Dornbusch', 'Rosa_Roth', 'creator', 'Stacy_Katzman', 'Rosa_Roth', 'lastAired', '1946-12-17', 'Rosa_Roth', 'starring', 'Bruce_Matthews', '']]}
# 1 ["Russian_Women's_Football_Championship country Turkey Kidsgrove_Athletic_F.C. ground Estadio_Once_de_Noviembre Kidsgrove_Athletic_F.C. league Russian_Women's_Football_Championship Estadio_Once_de_Noviembre location Cajari Kidsgrove_Athletic_F.C. season 1892 "]
# subject_dict: {"Russian_Women's_Football_Championship": [["Russian_Women's_Football_Championship", 'country', 'Turkey', 'Kidsgrove_Athletic_F.C.', 'ground', 'Estadio_Once_de_Noviembre', 'Kidsgrove_Athletic_F.C.', 'league', "Russian_Women's_Football_Championship", 'Estadio_Once_de_Noviembre', 'location', 'Cajari', 'Kidsgrove_Athletic_F.C.', 'season', '1892', '']]}
# object_dict: {}
# merged_dict: {'0': [["Russian_Women's_Football_Championship", 'country', 'Turkey', 'Kidsgrove_Athletic_F.C.', 'ground', 'Estadio_Once_de_Noviembre', 'Kidsgrove_Athletic_F.C.', 'league', "Russian_Women's_Football_Championship", 'Estadio_Once_de_Noviembre', 'location', 'Cajari', 'Kidsgrove_Athletic_F.C.', 'season', '1892', '']]}
# 1 ['Bionico country Israel Bionico course Supersize Israel currency Fribourg_frank Bionico ingredient dried_cherry ']
# subject_dict: {'Bionico': [['Bionico', 'country', 'Israel', 'Bionico', 'course', 'Supersize', 'Israel', 'currency', 'Fribourg_frank', 'Bionico', 'ingredient', 'dried_cherry', '']]}
# object_dict: {}
# merged_dict: {'0': [['Bionico', 'country', 'Israel', 'Bionico', 'course', 'Supersize', 'Israel', 'currency', 'Fribourg_frank', 'Bionico', 'ingredient', 'dried_cherry', '']]}
# 1 ['Novonor city Ali_Chuk Brazil leader Clive_Sarstedt Novonor regionServed Brazil Ali_Chuk type Bloomfield ']
# subject_dict: {'Novonor': [['Novonor', 'city', 'Ali_Chuk', 'Brazil', 'leader', 'Clive_Sarstedt', 'Novonor', 'regionServed', 'Brazil', 'Ali_Chuk', 'type', 'Bloomfield', '']]}
# object_dict: {}
# merged_dict: {'0': [['Novonor', 'city', 'Ali_Chuk', 'Brazil', 'leader', 'Clive_Sarstedt', 'Novonor', 'regionServed', 'Brazil', 'Ali_Chuk', 'type', 'Bloomfield', '']]}
# 1 ['Jacqueline_Cochran club Sporting_CP Kent_Football_United_F.C. ground Stade_de_France Sporting_CP manager Adam_de_la_Halle Jacqueline_Cochran youthclub Kent_Football_United_F.C. ']
# subject_dict: {'Jacqueline_Cochran': [['Jacqueline_Cochran', 'club', 'Sporting_CP', 'Kent_Football_United_F.C.', 'ground', 'Stade_de_France', 'Sporting_CP', 'manager', 'Adam_de_la_Halle', 'Jacqueline_Cochran', 'youthclub', 'Kent_Football_United_F.C.', '']]}
# object_dict: {}
# merged_dict: {'0': [['Jacqueline_Cochran', 'club', 'Sporting_CP', 'Kent_Football_United_F.C.', 'ground', 'Stade_de_France', 'Sporting_CP', 'manager', 'Adam_de_la_Halle', 'Jacqueline_Cochran', 'youthclub', 'Kent_Football_United_F.C.', '']]}
# 1 ['Álvaro_Aparicio club West_Didsbury_and_Chorlton_A.F.C. West_Didsbury_and_Chorlton_A.F.C. manager Amitabh_Bachchan Álvaro_Aparicio youthclub Blyth_Spartans_A.F.C. ']
# subject_dict: {'Álvaro_Aparicio': [['Álvaro_Aparicio', 'club', 'West_Didsbury_and_Chorlton_A.F.C.', 'West_Didsbury_and_Chorlton_A.F.C.', 'manager', 'Amitabh_Bachchan', 'Álvaro_Aparicio', 'youthclub', 'Blyth_Spartans_A.F.C.', '']]}
# object_dict: {}
# merged_dict: {'0': [['Álvaro_Aparicio', 'club', 'West_Didsbury_and_Chorlton_A.F.C.', 'West_Didsbury_and_Chorlton_A.F.C.', 'manager', 'Amitabh_Bachchan', 'Álvaro_Aparicio', 'youthclub', 'Blyth_Spartans_A.F.C.', '']]}
# 1 ['Bedford_College affiliation Kinnaird_College_for_Women Bedford_College campus "Ruth_Ribicoff" SWIFT location Rio_de_Janeiro Bedford_College sportsOffered floorball Bedford_College wasGivenTheTechnicalCampusStatusBy SWIFT ']
# subject_dict: {'Bedford_College': [['Bedford_College', 'affiliation', 'Kinnaird_College_for_Women', 'Bedford_College', 'campus', '"Ruth_Ribicoff"', 'SWIFT', 'location', 'Rio_de_Janeiro', 'Bedford_College', 'sportsOffered', 'floorball', 'Bedford_College', 'wasGivenTheTechnicalCampusStatusBy', 'SWIFT', '']]}
# object_dict: {}
# merged_dict: {'0': [['Bedford_College', 'affiliation', 'Kinnaird_College_for_Women', 'Bedford_College', 'campus', '"Ruth_Ribicoff"', 'SWIFT', 'location', 'Rio_de_Janeiro', 'Bedford_College', 'sportsOffered', 'floorball', 'Bedford_College', 'wasGivenTheTechnicalCampusStatusBy', 'SWIFT', '']]}
# 1 ["Mermaid_(Train_song) genre dance-pop Mermaid_(Train_song) genre jazz_rap jazz_rap stylisticOrigin Tswana_music dance-pop stylisticOrigin Ruba'i "]
# subject_dict: {'Mermaid_(Train_song)': [['Mermaid_(Train_song)', 'genre', 'dance-pop', 'Mermaid_(Train_song)', 'genre', 'jazz_rap', 'jazz_rap', 'stylisticOrigin', 'Tswana_music', 'dance-pop', 'stylisticOrigin', "Ruba'i", '']]}
# object_dict: {}
# merged_dict: {'0': [['Mermaid_(Train_song)', 'genre', 'dance-pop', 'Mermaid_(Train_song)', 'genre', 'jazz_rap', 'jazz_rap', 'stylisticOrigin', 'Tswana_music', 'dance-pop', 'stylisticOrigin', "Ruba'i", '']]}
# 1 ["Patricio_Aylwin birthPlace A.C._ChievoVerona Beakman's_World broadcastedBy Konica_Minolta Konica_Minolta city Broadcasting_House_Dornbusch Beakman's_World firstAired 1726-01-01 Beakman's_World starring Patricio_Aylwin "]
# subject_dict: {'Patricio_Aylwin': [['Patricio_Aylwin', 'birthPlace', 'A.C._ChievoVerona', "Beakman's_World", 'broadcastedBy', 'Konica_Minolta', 'Konica_Minolta', 'city', 'Broadcasting_House_Dornbusch', "Beakman's_World", 'firstAired', '1726-01-01', "Beakman's_World", 'starring', 'Patricio_Aylwin', '']]}
# object_dict: {}
# merged_dict: {'0': [['Patricio_Aylwin', 'birthPlace', 'A.C._ChievoVerona', "Beakman's_World", 'broadcastedBy', 'Konica_Minolta', 'Konica_Minolta', 'city', 'Broadcasting_House_Dornbusch', "Beakman's_World", 'firstAired', '1726-01-01', "Beakman's_World", 'starring', 'Patricio_Aylwin', '']]}
# 1 ['Mermaid_(Train_song) followedBy Allegro_Film Allegro_Film followedBy In_a_Reverie Mermaid_(Train_song) genre pop-punk ']
# subject_dict: {'Mermaid_(Train_song)': [['Mermaid_(Train_song)', 'followedBy', 'Allegro_Film', 'Allegro_Film', 'followedBy', 'In_a_Reverie', 'Mermaid_(Train_song)', 'genre', 'pop-punk', '']]}
# object_dict: {}
# merged_dict: {'0': [['Mermaid_(Train_song)', 'followedBy', 'Allegro_Film', 'Allegro_Film', 'followedBy', 'In_a_Reverie', 'Mermaid_(Train_song)', 'genre', 'pop-punk', '']]}
# 1 ['Françoise_Sagan birthPlace Israel Israel governmentType white_ethnostate Israel percentageOfAreaWater 89.0 Françoise_Sagan residence Yangquan Françoise_Sagan residence Israel ']
# subject_dict: {'Françoise_Sagan': [['Françoise_Sagan', 'birthPlace', 'Israel', 'Israel', 'governmentType', 'white_ethnostate', 'Israel', 'percentageOfAreaWater', '89.0', 'Françoise_Sagan', 'residence', 'Yangquan', 'Françoise_Sagan', 'residence', 'Israel', '']]}
# object_dict: {}
# merged_dict: {'0': [['Françoise_Sagan', 'birthPlace', 'Israel', 'Israel', 'governmentType', 'white_ethnostate', 'Israel', 'percentageOfAreaWater', '89.0', 'Françoise_Sagan', 'residence', 'Yangquan', 'Françoise_Sagan', 'residence', 'Israel', '']]}
# 1 ['Carlos_Henrique_dos_Santos_Souza activeYearsStartYear 1937-04-27 Flight_from_Ashiya director Carlos_Henrique_dos_Santos_Souza Flight_from_Ashiya editing Katarina_Ivanovska Flight_from_Ashiya producer Sachin_Tendulkar ']
# subject_dict: {'Carlos_Henrique_dos_Santos_Souza': [['Carlos_Henrique_dos_Santos_Souza', 'activeYearsStartYear', '1937-04-27', 'Flight_from_Ashiya', 'director', 'Carlos_Henrique_dos_Santos_Souza', 'Flight_from_Ashiya', 'editing', 'Katarina_Ivanovska', 'Flight_from_Ashiya', 'producer', 'Sachin_Tendulkar', '']]}
# object_dict: {}
# merged_dict: {'0': [['Carlos_Henrique_dos_Santos_Souza', 'activeYearsStartYear', '1937-04-27', 'Flight_from_Ashiya', 'director', 'Carlos_Henrique_dos_Santos_Souza', 'Flight_from_Ashiya', 'editing', 'Katarina_Ivanovska', 'Flight_from_Ashiya', 'producer', 'Sachin_Tendulkar', '']]}
# 1 ['Holger_Apfel birthPlace Brazil Holger_Apfel deathPlace Brazil Brazil ethnicGroup Azerbaijanis_in_Germany Holger_Apfel spouse Alliance_Films_Corporation ']
# subject_dict: {'Holger_Apfel': [['Holger_Apfel', 'birthPlace', 'Brazil', 'Holger_Apfel', 'deathPlace', 'Brazil', 'Brazil', 'ethnicGroup', 'Azerbaijanis_in_Germany', 'Holger_Apfel', 'spouse', 'Alliance_Films_Corporation', '']]}
# object_dict: {}
# merged_dict: {'0': [['Holger_Apfel', 'birthPlace', 'Brazil', 'Holger_Apfel', 'deathPlace', 'Brazil', 'Brazil', 'ethnicGroup', 'Azerbaijanis_in_Germany', 'Holger_Apfel', 'spouse', 'Alliance_Films_Corporation', '']]}
# 1 ['AF-borgen address 20_Fenchurch_Street AF-borgen architect A._P._J._Abdul_Kalam AF-borgen buildingStartDate 1929-06-11 De_La_Salle_University_School_of_Economics country Spain AF-borgen currentTenants De_La_Salle_University_School_of_Economics AF-borgen location California AF-borgen owner University_of_Milan ']
# subject_dict: {'AF-borgen': [['AF-borgen', 'address', '20_Fenchurch_Street', 'AF-borgen', 'architect', 'A._P._J._Abdul_Kalam', 'AF-borgen', 'buildingStartDate', '1929-06-11', 'De_La_Salle_University_School_of_Economics', 'country', 'Spain', 'AF-borgen', 'currentTenants', 'De_La_Salle_University_School_of_Economics', 'AF-borgen', 'location', 'California', 'AF-borgen', 'owner', 'University_of_Milan', '']]}
# object_dict: {}
# merged_dict: {'0': [['AF-borgen', 'address', '20_Fenchurch_Street', 'AF-borgen', 'architect', 'A._P._J._Abdul_Kalam', 'AF-borgen', 'buildingStartDate', '1929-06-11', 'De_La_Salle_University_School_of_Economics', 'country', 'Spain', 'AF-borgen', 'currentTenants', 'De_La_Salle_University_School_of_Economics', 'AF-borgen', 'location', 'California', 'AF-borgen', 'owner', 'University_of_Milan', '']]}
# 1 ['François_Mitterrand birthPlace Bydgoszcz François_Mitterrand height 94.0 Bydgoszcz timeZone Greenwich_Mean_Time Bydgoszcz timeZone UTC−00:44 ']
# subject_dict: {'François_Mitterrand': [['François_Mitterrand', 'birthPlace', 'Bydgoszcz', 'François_Mitterrand', 'height', '94.0', 'Bydgoszcz', 'timeZone', 'Greenwich_Mean_Time', 'Bydgoszcz', 'timeZone', 'UTC−00:44', '']]}
# object_dict: {}
# merged_dict: {'0': [['François_Mitterrand', 'birthPlace', 'Bydgoszcz', 'François_Mitterrand', 'height', '94.0', 'Bydgoszcz', 'timeZone', 'Greenwich_Mean_Time', 'Bydgoszcz', 'timeZone', 'UTC−00:44', '']]}
# 1 ['Sergei_Nikolayevich_Tereschenko birthDate 1908-05-02 Sergei_Nikolayevich_Tereschenko club SV_Werder_Bremen Sergei_Nikolayevich_Tereschenko currentclub Crown_Alexandra_F.C. SV_Werder_Bremen ground Degtyarsk Sergei_Nikolayevich_Tereschenko youthclub Sittingbourne_Community_F.C. ']
# subject_dict: {'Sergei_Nikolayevich_Tereschenko': [['Sergei_Nikolayevich_Tereschenko', 'birthDate', '1908-05-02', 'Sergei_Nikolayevich_Tereschenko', 'club', 'SV_Werder_Bremen', 'Sergei_Nikolayevich_Tereschenko', 'currentclub', 'Crown_Alexandra_F.C.', 'SV_Werder_Bremen', 'ground', 'Degtyarsk', 'Sergei_Nikolayevich_Tereschenko', 'youthclub', 'Sittingbourne_Community_F.C.', '']]}
# object_dict: {}
# merged_dict: {'0': [['Sergei_Nikolayevich_Tereschenko', 'birthDate', '1908-05-02', 'Sergei_Nikolayevich_Tereschenko', 'club', 'SV_Werder_Bremen', 'Sergei_Nikolayevich_Tereschenko', 'currentclub', 'Crown_Alexandra_F.C.', 'SV_Werder_Bremen', 'ground', 'Degtyarsk', 'Sergei_Nikolayevich_Tereschenko', 'youthclub', 'Sittingbourne_Community_F.C.', '']]}
# 1 ['Yemeni_League champions Phoenix_Sports_F.C. Trafford_F.C. ground KLFA_Stadium Trafford_F.C. league Yemeni_League Trafford_F.C. numberOfMembers 418476000000.0 ']
# subject_dict: {'Yemeni_League': [['Yemeni_League', 'champions', 'Phoenix_Sports_F.C.', 'Trafford_F.C.', 'ground', 'KLFA_Stadium', 'Trafford_F.C.', 'league', 'Yemeni_League', 'Trafford_F.C.', 'numberOfMembers', '418476000000.0', '']]}
# object_dict: {}
# merged_dict: {'0': [['Yemeni_League', 'champions', 'Phoenix_Sports_F.C.', 'Trafford_F.C.', 'ground', 'KLFA_Stadium', 'Trafford_F.C.', 'league', 'Yemeni_League', 'Trafford_F.C.', 'numberOfMembers', '418476000000.0', '']]}
# 1 ['Constantim isPartOf Jalisco Jalisco leader Decius Constantim leaderTitle Oberpräsident ']
# subject_dict: {'Constantim': [['Constantim', 'isPartOf', 'Jalisco', 'Jalisco', 'leader', 'Decius', 'Constantim', 'leaderTitle', 'Oberpräsident', '']]}
# object_dict: {}
# merged_dict: {'0': [['Constantim', 'isPartOf', 'Jalisco', 'Jalisco', 'leader', 'Decius', 'Constantim', 'leaderTitle', 'Oberpräsident', '']]}
# 1 ['Nav_Canada city Calzada_de_Valdunciel Carriel_Sur_International_Airport operatingOrganisation Nav_Canada Carriel_Sur_International_Airport runwayLength 16800 ']
# subject_dict: {'Nav_Canada': [['Nav_Canada', 'city', 'Calzada_de_Valdunciel', 'Carriel_Sur_International_Airport', 'operatingOrganisation', 'Nav_Canada', 'Carriel_Sur_International_Airport', 'runwayLength', '16800', '']]}
# object_dict: {}
# merged_dict: {'0': [['Nav_Canada', 'city', 'Calzada_de_Valdunciel', 'Carriel_Sur_International_Airport', 'operatingOrganisation', 'Nav_Canada', 'Carriel_Sur_International_Airport', 'runwayLength', '16800', '']]}
# 1 ["Deathdream author Ludwig_van_Beethoven Deathdream followedBy Don_Quixote The_End:_Hitler's_Germany_1944–45 literaryGenre fantasy_film The_End:_Hitler's_Germany_1944–45 literaryGenre dark_fantasy Deathdream precededBy The_End:_Hitler's_Germany_1944–45 "]
# subject_dict: {'Deathdream': [['Deathdream', 'author', 'Ludwig_van_Beethoven', 'Deathdream', 'followedBy', 'Don_Quixote', "The_End:_Hitler's_Germany_1944–45", 'literaryGenre', 'fantasy_film', "The_End:_Hitler's_Germany_1944–45", 'literaryGenre', 'dark_fantasy', 'Deathdream', 'precededBy', "The_End:_Hitler's_Germany_1944–45", '']]}
# object_dict: {}
# merged_dict: {'0': [['Deathdream', 'author', 'Ludwig_van_Beethoven', 'Deathdream', 'followedBy', 'Don_Quixote', "The_End:_Hitler's_Germany_1944–45", 'literaryGenre', 'fantasy_film', "The_End:_Hitler's_Germany_1944–45", 'literaryGenre', 'dark_fantasy', 'Deathdream', 'precededBy', "The_End:_Hitler's_Germany_1944–45", '']]}
# 1 ['Barking_and_Dagenham_College academicStaffSize "\'\'Alvinegro" Barking_and_Dagenham_College affiliation Zhejiang_Chinese_Medical_University Barking_and_Dagenham_College campus Dijon Zhejiang_Chinese_Medical_University city Postojna Barking_and_Dagenham_College director Stacy_Katzman German_Central_Bone_Marrow_Donor_Register location Kolkata Barking_and_Dagenham_College wasGivenTheTechnicalCampusStatusBy German_Central_Bone_Marrow_Donor_Register ']
# subject_dict: {'Barking_and_Dagenham_College': [['Barking_and_Dagenham_College', 'academicStaffSize', '"\'\'Alvinegro"', 'Barking_and_Dagenham_College', 'affiliation', 'Zhejiang_Chinese_Medical_University', 'Barking_and_Dagenham_College', 'campus', 'Dijon', 'Zhejiang_Chinese_Medical_University', 'city', 'Postojna', 'Barking_and_Dagenham_College', 'director', 'Stacy_Katzman', 'German_Central_Bone_Marrow_Donor_Register', 'location', 'Kolkata', 'Barking_and_Dagenham_College', 'wasGivenTheTechnicalCampusStatusBy', 'German_Central_Bone_Marrow_Donor_Register', '']]}
# object_dict: {}
# merged_dict: {'0': [['Barking_and_Dagenham_College', 'academicStaffSize', '"\'\'Alvinegro"', 'Barking_and_Dagenham_College', 'affiliation', 'Zhejiang_Chinese_Medical_University', 'Barking_and_Dagenham_College', 'campus', 'Dijon', 'Zhejiang_Chinese_Medical_University', 'city', 'Postojna', 'Barking_and_Dagenham_College', 'director', 'Stacy_Katzman', 'German_Central_Bone_Marrow_Donor_Register', 'location', 'Kolkata', 'Barking_and_Dagenham_College', 'wasGivenTheTechnicalCampusStatusBy', 'German_Central_Bone_Marrow_Donor_Register', '']]}
# 1 ['University_of_Southern_Brittany campus Lagny-sur-Marne Lagny-sur-Marne country Turkey Turkey governmentType Denmark University_of_Southern_Brittany numberOfStudents 16800 ']
# subject_dict: {'University_of_Southern_Brittany': [['University_of_Southern_Brittany', 'campus', 'Lagny-sur-Marne', 'Lagny-sur-Marne', 'country', 'Turkey', 'Turkey', 'governmentType', 'Denmark', 'University_of_Southern_Brittany', 'numberOfStudents', '16800', '']]}
# object_dict: {}
# merged_dict: {'0': [['University_of_Southern_Brittany', 'campus', 'Lagny-sur-Marne', 'Lagny-sur-Marne', 'country', 'Turkey', 'Turkey', 'governmentType', 'Denmark', 'University_of_Southern_Brittany', 'numberOfStudents', '16800', '']]}
# 1 ['Santa_Apolónia_Station address 11_Diagonal_Street Santa_Apolónia_Station architect Cyndi_Lauper Santa_Apolónia_Station buildingStartDate "1923-11-18" Santa_Apolónia_Station completionDate 1726-01-01 Indian_Institutes_of_Management country Turkey Santa_Apolónia_Station currentTenants Indian_Institutes_of_Management ']
# subject_dict: {'Santa_Apolónia_Station': [['Santa_Apolónia_Station', 'address', '11_Diagonal_Street', 'Santa_Apolónia_Station', 'architect', 'Cyndi_Lauper', 'Santa_Apolónia_Station', 'buildingStartDate', '"1923-11-18"', 'Santa_Apolónia_Station', 'completionDate', '1726-01-01', 'Indian_Institutes_of_Management', 'country', 'Turkey', 'Santa_Apolónia_Station', 'currentTenants', 'Indian_Institutes_of_Management', '']]}
# object_dict: {}
# merged_dict: {'0': [['Santa_Apolónia_Station', 'address', '11_Diagonal_Street', 'Santa_Apolónia_Station', 'architect', 'Cyndi_Lauper', 'Santa_Apolónia_Station', 'buildingStartDate', '"1923-11-18"', 'Santa_Apolónia_Station', 'completionDate', '1726-01-01', 'Indian_Institutes_of_Management', 'country', 'Turkey', 'Santa_Apolónia_Station', 'currentTenants', 'Indian_Institutes_of_Management', '']]}
# 1 ['Doctor_Who broadcastedBy Lamborghini Lamborghini city Broadcasting_House Doctor_Who creator Steve_Bright Doctor_Who lastAired 1908-05-02 ']
# subject_dict: {'Doctor_Who': [['Doctor_Who', 'broadcastedBy', 'Lamborghini', 'Lamborghini', 'city', 'Broadcasting_House', 'Doctor_Who', 'creator', 'Steve_Bright', 'Doctor_Who', 'lastAired', '1908-05-02', '']]}
# object_dict: {}
# merged_dict: {'0': [['Doctor_Who', 'broadcastedBy', 'Lamborghini', 'Lamborghini', 'city', 'Broadcasting_House', 'Doctor_Who', 'creator', 'Steve_Bright', 'Doctor_Who', 'lastAired', '1908-05-02', '']]}
# 1 ['Bionico country Spain Bionico course paella paella dishVariation bika_ambon ']
# subject_dict: {'Bionico': [['Bionico', 'country', 'Spain', 'Bionico', 'course', 'paella', 'paella', 'dishVariation', 'bika_ambon', '']]}
# object_dict: {}
# merged_dict: {'0': [['Bionico', 'country', 'Spain', 'Bionico', 'course', 'paella', 'paella', 'dishVariation', 'bika_ambon', '']]}
# 1 ['Bionico country Israel Bionico course serviettenknödel Israel currency British_North_Borneo_dollar Israel demonym South_Australians Bionico ingredient Granola Israel leader William_Shakespeare Bionico region Valle_de_Ignacio_Allende ']
# subject_dict: {'Bionico': [['Bionico', 'country', 'Israel', 'Bionico', 'course', 'serviettenknödel', 'Israel', 'currency', 'British_North_Borneo_dollar', 'Israel', 'demonym', 'South_Australians', 'Bionico', 'ingredient', 'Granola', 'Israel', 'leader', 'William_Shakespeare', 'Bionico', 'region', 'Valle_de_Ignacio_Allende', '']]}
# object_dict: {}
# merged_dict: {'0': [['Bionico', 'country', 'Israel', 'Bionico', 'course', 'serviettenknödel', 'Israel', 'currency', 'British_North_Borneo_dollar', 'Israel', 'demonym', 'South_Australians', 'Bionico', 'ingredient', 'Granola', 'Israel', 'leader', 'William_Shakespeare', 'Bionico', 'region', 'Valle_de_Ignacio_Allende', '']]}
# 1 ['Stacy_Lewis club A.C._ChievoVerona Stacy_Lewis currentclub Lech_Poznań A.C._ChievoVerona ground Lyuban A.C._ChievoVerona manager Tommi_Nikunen Stacy_Lewis youthclub Frickley_Athletic_F.C. ']
# subject_dict: {'Stacy_Lewis': [['Stacy_Lewis', 'club', 'A.C._ChievoVerona', 'Stacy_Lewis', 'currentclub', 'Lech_Poznań', 'A.C._ChievoVerona', 'ground', 'Lyuban', 'A.C._ChievoVerona', 'manager', 'Tommi_Nikunen', 'Stacy_Lewis', 'youthclub', 'Frickley_Athletic_F.C.', '']]}
# object_dict: {}
# merged_dict: {'0': [['Stacy_Lewis', 'club', 'A.C._ChievoVerona', 'Stacy_Lewis', 'currentclub', 'Lech_Poznań', 'A.C._ChievoVerona', 'ground', 'Lyuban', 'A.C._ChievoVerona', 'manager', 'Tommi_Nikunen', 'Stacy_Lewis', 'youthclub', 'Frickley_Athletic_F.C.', '']]}
# 1 ['The_Academy_in_Peril artist Anderson_Bruford_Wakeman_Howe Anderson_Bruford_Wakeman_Howe formerBandMember Laura_Robson Zic_Zac_Music_Company_Sp._z_o.o. parentCompany ZDF_Studios The_Academy_in_Peril recordLabel Zic_Zac_Music_Company_Sp._z_o.o. ']
# subject_dict: {'The_Academy_in_Peril': [['The_Academy_in_Peril', 'artist', 'Anderson_Bruford_Wakeman_Howe', 'Anderson_Bruford_Wakeman_Howe', 'formerBandMember', 'Laura_Robson', 'Zic_Zac_Music_Company_Sp._z_o.o.', 'parentCompany', 'ZDF_Studios', 'The_Academy_in_Peril', 'recordLabel', 'Zic_Zac_Music_Company_Sp._z_o.o.', '']]}
# object_dict: {}
# merged_dict: {'0': [['The_Academy_in_Peril', 'artist', 'Anderson_Bruford_Wakeman_Howe', 'Anderson_Bruford_Wakeman_Howe', 'formerBandMember', 'Laura_Robson', 'Zic_Zac_Music_Company_Sp._z_o.o.', 'parentCompany', 'ZDF_Studios', 'The_Academy_in_Peril', 'recordLabel', 'Zic_Zac_Music_Company_Sp._z_o.o.', '']]}
# 1 ['Gralheira country United_States United_States leaderTitle Chief_Justice_of_the_United_States Gralheira populationDensity 29000 Gralheira utcOffset −6 ']
# subject_dict: {'Gralheira': [['Gralheira', 'country', 'United_States', 'United_States', 'leaderTitle', 'Chief_Justice_of_the_United_States', 'Gralheira', 'populationDensity', '29000', 'Gralheira', 'utcOffset', '−6', '']]}
# object_dict: {}
# merged_dict: {'0': [['Gralheira', 'country', 'United_States', 'United_States', 'leaderTitle', 'Chief_Justice_of_the_United_States', 'Gralheira', 'populationDensity', '29000', 'Gralheira', 'utcOffset', '−6', '']]}
# 1 ['Bayan_College_for_Science_and_Technology campus Steve_Bright Bayan_College_for_Science_and_Technology country Haiti Bayan_College_for_Science_and_Technology director Alliance_Films_Corporation Bayan_College_for_Science_and_Technology established 2000 SWIFT location London Bayan_College_for_Science_and_Technology wasGivenTheTechnicalCampusStatusBy SWIFT ']
# subject_dict: {'Bayan_College_for_Science_and_Technology': [['Bayan_College_for_Science_and_Technology', 'campus', 'Steve_Bright', 'Bayan_College_for_Science_and_Technology', 'country', 'Haiti', 'Bayan_College_for_Science_and_Technology', 'director', 'Alliance_Films_Corporation', 'Bayan_College_for_Science_and_Technology', 'established', '2000', 'SWIFT', 'location', 'London', 'Bayan_College_for_Science_and_Technology', 'wasGivenTheTechnicalCampusStatusBy', 'SWIFT', '']]}
# object_dict: {}
# merged_dict: {'0': [['Bayan_College_for_Science_and_Technology', 'campus', 'Steve_Bright', 'Bayan_College_for_Science_and_Technology', 'country', 'Haiti', 'Bayan_College_for_Science_and_Technology', 'director', 'Alliance_Films_Corporation', 'Bayan_College_for_Science_and_Technology', 'established', '2000', 'SWIFT', 'location', 'London', 'Bayan_College_for_Science_and_Technology', 'wasGivenTheTechnicalCampusStatusBy', 'SWIFT', '']]}
# 1 ['Double_Dare associatedBand/associatedMusicalArtist Quentin_Tarantino Double_Dare associatedBand/associatedMusicalArtist Lewis_Hamilton Mermaid_(Train_song) writer Katrina_Kaif Mermaid_(Train_song) writer Double_Dare ']
# subject_dict: {'Double_Dare': [['Double_Dare', 'associatedBand/associatedMusicalArtist', 'Quentin_Tarantino', 'Double_Dare', 'associatedBand/associatedMusicalArtist', 'Lewis_Hamilton', 'Mermaid_(Train_song)', 'writer', 'Katrina_Kaif', 'Mermaid_(Train_song)', 'writer', 'Double_Dare', '']]}
# object_dict: {}
# merged_dict: {'0': [['Double_Dare', 'associatedBand/associatedMusicalArtist', 'Quentin_Tarantino', 'Double_Dare', 'associatedBand/associatedMusicalArtist', 'Lewis_Hamilton', 'Mermaid_(Train_song)', 'writer', 'Katrina_Kaif', 'Mermaid_(Train_song)', 'writer', 'Double_Dare', '']]}
# 1 ["Amiable_Child_Monument category Contributing_property Amiable_Child_Monument country People's_Republic_of_China Amiable_Child_Monument established 2000 Weld_County hasToItsNorth Cumberland_County_Pennsylvania Weld_County hasToItsSoutheast Carroll_County_Maryland Weld_County hasToItsWest Franklin_County_Pennsylvania Amiable_Child_Monument location Weld_County "]
# subject_dict: {'Amiable_Child_Monument': [['Amiable_Child_Monument', 'category', 'Contributing_property', 'Amiable_Child_Monument', 'country', "People's_Republic_of_China", 'Amiable_Child_Monument', 'established', '2000', 'Weld_County', 'hasToItsNorth', 'Cumberland_County_Pennsylvania', 'Weld_County', 'hasToItsSoutheast', 'Carroll_County_Maryland', 'Weld_County', 'hasToItsWest', 'Franklin_County_Pennsylvania', 'Amiable_Child_Monument', 'location', 'Weld_County', '']]}
# object_dict: {}
# merged_dict: {'0': [['Amiable_Child_Monument', 'category', 'Contributing_property', 'Amiable_Child_Monument', 'country', "People's_Republic_of_China", 'Amiable_Child_Monument', 'established', '2000', 'Weld_County', 'hasToItsNorth', 'Cumberland_County_Pennsylvania', 'Weld_County', 'hasToItsSoutheast', 'Carroll_County_Maryland', 'Weld_County', 'hasToItsWest', 'Franklin_County_Pennsylvania', 'Amiable_Child_Monument', 'location', 'Weld_County', '']]}
# 1 ['France governmentType Pakistani_nationalism Jeremias_Augustin residence California Jeremias_Augustin residence France ']
# subject_dict: {'France': [['France', 'governmentType', 'Pakistani_nationalism', 'Jeremias_Augustin', 'residence', 'California', 'Jeremias_Augustin', 'residence', 'France', '']]}
# object_dict: {}
# merged_dict: {'0': [['France', 'governmentType', 'Pakistani_nationalism', 'Jeremias_Augustin', 'residence', 'California', 'Jeremias_Augustin', 'residence', 'France', '']]}
# 1 ['Kate_Bush birthPlace Edirne Kate_Bush birthPlace Brazil Brazil currency Sri_Lankan_rupee Brazil officialLanguage Iban ']
# ...
# 1 ['Tarrant_County,_Texas country United_States Tarrant_County,_Texas countySeat Fort_Worth,_Texas Arlington,_Texas isPartOf Tarrant_County,_Texas Arlington,_Texas isPartOf Texas Texas largestCity Houston ']
# subject_dict: {'Tarrant_County,_Texas': [['Tarrant_County,_Texas', 'country', 'United_States', 'Tarrant_County,_Texas', 'countySeat', 'Fort_Worth,_Texas', 'Arlington,_Texas', 'isPartOf', 'Tarrant_County,_Texas', 'Arlington,_Texas', 'isPartOf', 'Texas', 'Texas', 'largestCity', 'Houston', '']]}
# object_dict: {}
# merged_dict: {'0': [['Tarrant_County,_Texas', 'country', 'United_States', 'Tarrant_County,_Texas', 'countySeat', 'Fort_Worth,_Texas', 'Arlington,_Texas', 'isPartOf', 'Tarrant_County,_Texas', 'Arlington,_Texas', 'isPartOf', 'Texas', 'Texas', 'largestCity', 'Houston', '']]}
# 1 ['Houston_Texans city Texas Atlanta_Falcons city Atlanta Akeem_Dent debutTeam Atlanta_Falcons Akeem_Dent formerTeam Houston_Texans ']
# subject_dict: {'Houston_Texans': [['Houston_Texans', 'city', 'Texas', 'Atlanta_Falcons', 'city', 'Atlanta', 'Akeem_Dent', 'debutTeam', 'Atlanta_Falcons', 'Akeem_Dent', 'formerTeam', 'Houston_Texans', '']]}
# object_dict: {}
# merged_dict: {'0': [['Houston_Texans', 'city', 'Texas', 'Atlanta_Falcons', 'city', 'Atlanta', 'Akeem_Dent', 'debutTeam', 'Atlanta_Falcons', 'Akeem_Dent', 'formerTeam', 'Houston_Texans', '']]}
# 1 ['Trane industry Building_materials Trane location Ireland Ireland location Europe Trane numberOfEmployees 29000 ']
# subject_dict: {'Trane': [['Trane', 'industry', 'Building_materials', 'Trane', 'location', 'Ireland', 'Ireland', 'location', 'Europe', 'Trane', 'numberOfEmployees', '29000', '']]}
# object_dict: {}
# merged_dict: {'0': [['Trane', 'industry', 'Building_materials', 'Trane', 'location', 'Ireland', 'Ireland', 'location', 'Europe', 'Trane', 'numberOfEmployees', '29000', '']]}
# 1 ['Alaa_Abdul-Zahra club Al-Khor_Sports_Club Alaa_Abdul-Zahra club Al_Kharaitiyat_SC Al-Khor_Sports_Club ground Al_Khor Al_Kharaitiyat_SC league Qatar_Stars_League Al_Kharaitiyat_SC manager Amar_Osim ']
# subject_dict: {'Alaa_Abdul-Zahra': [['Alaa_Abdul-Zahra', 'club', 'Al-Khor_Sports_Club', 'Alaa_Abdul-Zahra', 'club', 'Al_Kharaitiyat_SC', 'Al-Khor_Sports_Club', 'ground', 'Al_Khor', 'Al_Kharaitiyat_SC', 'league', 'Qatar_Stars_League', 'Al_Kharaitiyat_SC', 'manager', 'Amar_Osim', '']]}
# object_dict: {}
# merged_dict: {'0': [['Alaa_Abdul-Zahra', 'club', 'Al-Khor_Sports_Club', 'Alaa_Abdul-Zahra', 'club', 'Al_Kharaitiyat_SC', 'Al-Khor_Sports_Club', 'ground', 'Al_Khor', 'Al_Kharaitiyat_SC', 'league', 'Qatar_Stars_League', 'Al_Kharaitiyat_SC', 'manager', 'Amar_Osim', '']]}
# 1 ['Albert_Jennings_Fountain battle American_Civil_War Albert_Jennings_Fountain birthPlace New_York American_Civil_War commander Abraham_Lincoln New_York language Arabic ']
# subject_dict: {'Albert_Jennings_Fountain': [['Albert_Jennings_Fountain', 'battle', 'American_Civil_War', 'Albert_Jennings_Fountain', 'birthPlace', 'New_York', 'American_Civil_War', 'commander', 'Abraham_Lincoln', 'New_York', 'language', 'Arabic', '']]}
# object_dict: {}
# merged_dict: {'0': [['Albert_Jennings_Fountain', 'battle', 'American_Civil_War', 'Albert_Jennings_Fountain', 'birthPlace', 'New_York', 'American_Civil_War', 'commander', 'Abraham_Lincoln', 'New_York', 'language', 'Arabic', '']]}
# 1 ['Adare_Manor country Republic_of_Ireland Republic_of_Ireland currency Euro Republic_of_Ireland demonym Irish_people Republic_of_Ireland language English_language Republic_of_Ireland leader Enda_Kenny ']
# subject_dict: {'Adare_Manor': [['Adare_Manor', 'country', 'Republic_of_Ireland', 'Republic_of_Ireland', 'currency', 'Euro', 'Republic_of_Ireland', 'demonym', 'Irish_people', 'Republic_of_Ireland', 'language', 'English_language', 'Republic_of_Ireland', 'leader', 'Enda_Kenny', '']]}
# object_dict: {}
# merged_dict: {'0': [['Adare_Manor', 'country', 'Republic_of_Ireland', 'Republic_of_Ireland', 'currency', 'Euro', 'Republic_of_Ireland', 'demonym', 'Irish_people', 'Republic_of_Ireland', 'language', 'English_language', 'Republic_of_Ireland', 'leader', 'Enda_Kenny', '']]}
# 1 ['Addis_Ababa_City_Hall country Ethiopia Ethiopia language Amharic Ethiopia leader Mulatu_Teshome Addis_Ababa_City_Hall location Addis_Ababa ']
# subject_dict: {'Addis_Ababa_City_Hall': [['Addis_Ababa_City_Hall', 'country', 'Ethiopia', 'Ethiopia', 'language', 'Amharic', 'Ethiopia', 'leader', 'Mulatu_Teshome', 'Addis_Ababa_City_Hall', 'location', 'Addis_Ababa', '']]}
# object_dict: {}
# merged_dict: {'0': [['Addis_Ababa_City_Hall', 'country', 'Ethiopia', 'Ethiopia', 'language', 'Amharic', 'Ethiopia', 'leader', 'Mulatu_Teshome', 'Addis_Ababa_City_Hall', 'location', 'Addis_Ababa', '']]}
# 1 ['Aaron_Turner associatedBand/associatedMusicalArtist House_of_Low_Culture Aaron_Turner genre Black_metal Black_metal musicFusionGenre Death_metal ']
# subject_dict: {'Aaron_Turner': [['Aaron_Turner', 'associatedBand/associatedMusicalArtist', 'House_of_Low_Culture', 'Aaron_Turner', 'genre', 'Black_metal', 'Black_metal', 'musicFusionGenre', 'Death_metal', '']]}
# object_dict: {}
# merged_dict: {'0': [['Aaron_Turner', 'associatedBand/associatedMusicalArtist', 'House_of_Low_Culture', 'Aaron_Turner', 'genre', 'Black_metal', 'Black_metal', 'musicFusionGenre', 'Death_metal', '']]}
# 1 ['James_Craig_Watson deathPlace Madison,_Wisconsin 101_Helena discoverer James_Craig_Watson James_Craig_Watson nationality Canada 101_Helena orbitalPeriod 1516.6700000000003 (days) ']
# subject_dict: {'James_Craig_Watson': [['James_Craig_Watson', 'deathPlace', 'Madison,_Wisconsin', '101_Helena', 'discoverer', 'James_Craig_Watson', 'James_Craig_Watson', 'nationality', 'Canada', '101_Helena', 'orbitalPeriod', '1516.6700000000003', '(days)', '']]}
# object_dict: {}
# merged_dict: {'0': [['James_Craig_Watson', 'deathPlace', 'Madison,_Wisconsin', '101_Helena', 'discoverer', 'James_Craig_Watson', 'James_Craig_Watson', 'nationality', 'Canada', '101_Helena', 'orbitalPeriod', '1516.6700000000003', '(days)', '']]}
# 1 ['Binignit ingredient Sweet_potato Binignit mainIngredient Banana Sweet_potato order Solanales ']
# subject_dict: {'Binignit': [['Binignit', 'ingredient', 'Sweet_potato', 'Binignit', 'mainIngredient', 'Banana', 'Sweet_potato', 'order', 'Solanales', '']]}
# object_dict: {}
# merged_dict: {'0': [['Binignit', 'ingredient', 'Sweet_potato', 'Binignit', 'mainIngredient', 'Banana', 'Sweet_potato', 'order', 'Solanales', '']]}
# 1 ["Jazz derivative Funk Alison_O'Donnell genre Jazz Alison_O'Donnell recordLabel Kissing_Spell_Records "]
# subject_dict: {'Jazz': [['Jazz', 'derivative', 'Funk', "Alison_O'Donnell", 'genre', 'Jazz', "Alison_O'Donnell", 'recordLabel', 'Kissing_Spell_Records', '']]}
# object_dict: {}
# merged_dict: {'0': [['Jazz', 'derivative', 'Funk', "Alison_O'Donnell", 'genre', 'Jazz', "Alison_O'Donnell", 'recordLabel', 'Kissing_Spell_Records', '']]}
# 1 ['Alaa_Abdul-Zahra club Al-Khor_Sports_Club Alaa_Abdul-Zahra club Al_Kharaitiyat_SC Al-Khor_Sports_Club ground Al_Khor Al_Kharaitiyat_SC manager Amar_Osim ']
# subject_dict: {'Alaa_Abdul-Zahra': [['Alaa_Abdul-Zahra', 'club', 'Al-Khor_Sports_Club', 'Alaa_Abdul-Zahra', 'club', 'Al_Kharaitiyat_SC', 'Al-Khor_Sports_Club', 'ground', 'Al_Khor', 'Al_Kharaitiyat_SC', 'manager', 'Amar_Osim', '']]}
# object_dict: {}
# merged_dict: {'0': [['Alaa_Abdul-Zahra', 'club', 'Al-Khor_Sports_Club', 'Alaa_Abdul-Zahra', 'club', 'Al_Kharaitiyat_SC', 'Al-Khor_Sports_Club', 'ground', 'Al_Khor', 'Al_Kharaitiyat_SC', 'manager', 'Amar_Osim', '']]}
# 1 ['United_States capital Washington,_D.C. Taylor_County,_Texas country United_States Abilene,_Texas isPartOf Taylor_County,_Texas United_States language English_language United_States largestCity New_York_City ']
# subject_dict: {'United_States': [['United_States', 'capital', 'Washington,_D.C.', 'Taylor_County,_Texas', 'country', 'United_States', 'Abilene,_Texas', 'isPartOf', 'Taylor_County,_Texas', 'United_States', 'language', 'English_language', 'United_States', 'largestCity', 'New_York_City', '']]}
# object_dict: {}
# merged_dict: {'0': [['United_States', 'capital', 'Washington,_D.C.', 'Taylor_County,_Texas', 'country', 'United_States', 'Abilene,_Texas', 'isPartOf', 'Taylor_County,_Texas', 'United_States', 'language', 'English_language', 'United_States', 'largestCity', 'New_York_City', '']]}
# 1 ['United_States capital Washington,_D.C. Atlas_II countryOrigin United_States United_States ethnicGroup African_Americans United_States language English_language United_States leaderTitle President_of_the_United_States ']
# subject_dict: {'United_States': [['United_States', 'capital', 'Washington,_D.C.', 'Atlas_II', 'countryOrigin', 'United_States', 'United_States', 'ethnicGroup', 'African_Americans', 'United_States', 'language', 'English_language', 'United_States', 'leaderTitle', 'President_of_the_United_States', '']]}
# object_dict: {}
# merged_dict: {'0': [['United_States', 'capital', 'Washington,_D.C.', 'Atlas_II', 'countryOrigin', 'United_States', 'United_States', 'ethnicGroup', 'African_Americans', 'United_States', 'language', 'English_language', 'United_States', 'leaderTitle', 'President_of_the_United_States', '']]}
# 1 ['Alfons_Gorbach birthPlace County_of_Tyrol Alfons_Gorbach birthPlace Austria Alfons_Gorbach deathPlace Graz Austria language Austrian_German Austria leader Doris_Bures ']
# subject_dict: {'Alfons_Gorbach': [['Alfons_Gorbach', 'birthPlace', 'County_of_Tyrol', 'Alfons_Gorbach', 'birthPlace', 'Austria', 'Alfons_Gorbach', 'deathPlace', 'Graz', 'Austria', 'language', 'Austrian_German', 'Austria', 'leader', 'Doris_Bures', '']]}
# object_dict: {}
# merged_dict: {'0': [['Alfons_Gorbach', 'birthPlace', 'County_of_Tyrol', 'Alfons_Gorbach', 'birthPlace', 'Austria', 'Alfons_Gorbach', 'deathPlace', 'Graz', 'Austria', 'language', 'Austrian_German', 'Austria', 'leader', 'Doris_Bures', '']]}
# 1 ['Aaron_Deer genre Indie_rock Aaron_Deer instrument Keyboard_instrument Indie_rock stylisticOrigin Garage_rock Indie_rock stylisticOrigin New_wave_music ']
# subject_dict: {'Aaron_Deer': [['Aaron_Deer', 'genre', 'Indie_rock', 'Aaron_Deer', 'instrument', 'Keyboard_instrument', 'Indie_rock', 'stylisticOrigin', 'Garage_rock', 'Indie_rock', 'stylisticOrigin', 'New_wave_music', '']]}
# object_dict: {}
# merged_dict: {'0': [['Aaron_Deer', 'genre', 'Indie_rock', 'Aaron_Deer', 'instrument', 'Keyboard_instrument', 'Indie_rock', 'stylisticOrigin', 'Garage_rock', 'Indie_rock', 'stylisticOrigin', 'New_wave_music', '']]}
# 1 ['Arròs_negre country Spain Spain demonym Spaniards Spain leader Felipe_VI_of_Spain Catalonia leader Parliament_of_Catalonia Arròs_negre region Catalonia ']
# subject_dict: {'Arròs_negre': [['Arròs_negre', 'country', 'Spain', 'Spain', 'demonym', 'Spaniards', 'Spain', 'leader', 'Felipe_VI_of_Spain', 'Catalonia', 'leader', 'Parliament_of_Catalonia', 'Arròs_negre', 'region', 'Catalonia', '']]}
# object_dict: {}
# merged_dict: {'0': [['Arròs_negre', 'country', 'Spain', 'Spain', 'demonym', 'Spaniards', 'Spain', 'leader', 'Felipe_VI_of_Spain', 'Catalonia', 'leader', 'Parliament_of_Catalonia', 'Arròs_negre', 'region', 'Catalonia', '']]}
# 1 ['Adare_Manor country Republic_of_Ireland Republic_of_Ireland language Irish_language Republic_of_Ireland leader Enda_Kenny ']
# subject_dict: {'Adare_Manor': [['Adare_Manor', 'country', 'Republic_of_Ireland', 'Republic_of_Ireland', 'language', 'Irish_language', 'Republic_of_Ireland', 'leader', 'Enda_Kenny', '']]}
# object_dict: {}
# merged_dict: {'0': [['Adare_Manor', 'country', 'Republic_of_Ireland', 'Republic_of_Ireland', 'language', 'Irish_language', 'Republic_of_Ireland', 'leader', 'Enda_Kenny', '']]}
# 1 ['Dublin isPartOf Republic_of_Ireland 3Arena location Dublin 3Arena owner Live_Nation_Entertainment ']
# subject_dict: {'Dublin': [['Dublin', 'isPartOf', 'Republic_of_Ireland', '3Arena', 'location', 'Dublin', '3Arena', 'owner', 'Live_Nation_Entertainment', '']]}
# object_dict: {}
# merged_dict: {'0': [['Dublin', 'isPartOf', 'Republic_of_Ireland', '3Arena', 'location', 'Dublin', '3Arena', 'owner', 'Live_Nation_Entertainment', '']]}
# 1 ['San_Sebastián_de_los_Reyes country Spain Adolfo_Suárez_Madrid–Barajas_Airport elevationAboveTheSeaLevel 610.0 San_Sebastián_de_los_Reyes isPartOf Community_of_Madrid Adolfo_Suárez_Madrid–Barajas_Airport location San_Sebastián_de_los_Reyes ']
# subject_dict: {'San_Sebastián_de_los_Reyes': [['San_Sebastián_de_los_Reyes', 'country', 'Spain', 'Adolfo_Suárez_Madrid–Barajas_Airport', 'elevationAboveTheSeaLevel', '610.0', 'San_Sebastián_de_los_Reyes', 'isPartOf', 'Community_of_Madrid', 'Adolfo_Suárez_Madrid–Barajas_Airport', 'location', 'San_Sebastián_de_los_Reyes', '']]}
# object_dict: {}
# merged_dict: {'0': [['San_Sebastián_de_los_Reyes', 'country', 'Spain', 'Adolfo_Suárez_Madrid–Barajas_Airport', 'elevationAboveTheSeaLevel', '610.0', 'San_Sebastián_de_los_Reyes', 'isPartOf', 'Community_of_Madrid', 'Adolfo_Suárez_Madrid–Barajas_Airport', 'location', 'San_Sebastián_de_los_Reyes', '']]}
# 1 ['11th_Mississippi_Infantry_Monument category Contributing_property 11th_Mississippi_Infantry_Monument established 2000 Adams_County,_Pennsylvania hasToItsNorth Cumberland_County,_Pennsylvania Adams_County,_Pennsylvania hasToItsSoutheast Carroll_County,_Maryland Adams_County,_Pennsylvania hasToItsWest Franklin_County,_Pennsylvania 11th_Mississippi_Infantry_Monument location Adams_County,_Pennsylvania 11th_Mississippi_Infantry_Monument municipality Gettysburg,_Pennsylvania ']
# subject_dict: {'11th_Mississippi_Infantry_Monument': [['11th_Mississippi_Infantry_Monument', 'category', 'Contributing_property', '11th_Mississippi_Infantry_Monument', 'established', '2000', 'Adams_County,_Pennsylvania', 'hasToItsNorth', 'Cumberland_County,_Pennsylvania', 'Adams_County,_Pennsylvania', 'hasToItsSoutheast', 'Carroll_County,_Maryland', 'Adams_County,_Pennsylvania', 'hasToItsWest', 'Franklin_County,_Pennsylvania', '11th_Mississippi_Infantry_Monument', 'location', 'Adams_County,_Pennsylvania', '11th_Mississippi_Infantry_Monument', 'municipality', 'Gettysburg,_Pennsylvania', '']]}
# object_dict: {}
# merged_dict: {'0': [['11th_Mississippi_Infantry_Monument', 'category', 'Contributing_property', '11th_Mississippi_Infantry_Monument', 'established', '2000', 'Adams_County,_Pennsylvania', 'hasToItsNorth', 'Cumberland_County,_Pennsylvania', 'Adams_County,_Pennsylvania', 'hasToItsSoutheast', 'Carroll_County,_Maryland', 'Adams_County,_Pennsylvania', 'hasToItsWest', 'Franklin_County,_Pennsylvania', '11th_Mississippi_Infantry_Monument', 'location', 'Adams_County,_Pennsylvania', '11th_Mississippi_Infantry_Monument', 'municipality', 'Gettysburg,_Pennsylvania', '']]}
#    id                                            triples  \
# 0   0               A-Rosa_Luna shipOrdered 2004-01-22
# 1   1        Aaron_S._Daggett birthPlace Greene,_Maine
# 2   2  Houston_Texans city Texas Houston_Texans city ...
# 3   3  Al_Asad_Airbase location "Al Anbar Province, I...
# 4   4  Antwerp_International_Airport cityServed Antwe...
#
#                                            data_unit  \
# 0                A-Rosa_Luna shipOrdered 2004-01-22
# 1         Aaron_S._Daggett birthPlace Greene,_Maine
# 2  Houston_Texans city Texas Houston_Texans city ...
# 3  Al_Asad_Airbase location "Al Anbar Province, I...
# 4  Antwerp_International_Airport cityServed Antwe...
#
#                                               actual                    shape  \
# 0  The A-Rosa Luna ship was ordered on January 22...                  (X (X))
# 1  The birth place of Aaron S. Daggett is Greene,...                  (X (X))
# 2  Akeem Dent, who debuted with the Atlanta Falco...  (X (X (X)) (X (X) (X)))
# 3  The Al Asad Airbase is situated in the Al Anba...          (X (X) (X) (X))
# 4  Bart De Wever is the mayor of Antwerp, which i...              (X (X (X)))
#
#   shape_type  local_size  size
# 0        NaN           1     1
# 1        NaN           1     1
# 2      mixed           1     5
# 3    sibling           1     3
# 4      chain           1     2

# %%
def split_dict(dict_to_split):
    new_dict = {}
    for key, value in dict_to_split.items():
        num_chunks = (len(value) + 2) // 3  # Calcoliamo il numero di chunk necessari
        for i in range(num_chunks):
            new_key = f"{key}_{i}" if i > 0 else key  # Creiamo una nuova chiave con indice se necessario
            start = i * 3
            end = min((i + 1) * 3, len(value))
            new_dict[new_key] = value[start:end]  # Aggiungiamo i valori corrispondenti
    return new_dict

dict_to_split = {'0': [['William_Anders', 'mission', 'Apollo_8'], ['Apollo_8', 'crew1Up', 'Frank_Borman'], ['Apollo_8', 'crew2Up', 'Buzz_Aldrin'], ['Apollo_8', 'operator', 'NASA']]}

split_dict_result = split_dict(dict_to_split)

for key, value in split_dict_result.items():
    print(f"{key}: {value}")
# Out:
# 0: [['William_Anders', 'mission', 'Apollo_8'], ['Apollo_8', 'crew1Up', 'Frank_Borman'], ['Apollo_8', 'crew2Up', 'Buzz_Aldrin']]
# 0_1: [['Apollo_8', 'operator', 'NASA']]
